# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 10.5 - Analysing Streaming Data with Kafka

# %% [markdown]
# ## Introduction

# %% [markdown]
# **Note**: this notebook is to be run in Google Colab on your Google Drive. It will not work locally on your computer.
#
# The purpose of this lab is to gain experience in working with streaming data, using Apache Kafka installed on Google Colaboratory (Colab). You will see how a simple streaming dashboard data is created using the Dash library and simulate live model scoring in monitoring a machine learning model.
#
# Apache Kafka is an open-source distributed publish-subscribe messaging system that maintains streams of messages in topics. It has become a highly popular streaming platform for real-time applications.
#
# In Google Colab, a virtual machine is automatically set up to execute your code. The maximum lifetime of such a machine is 12 hours. Note that notebooks will be disconnected from virtual machines if left idle. If this happens simple click on the Connect button to reconnect. If the kernel needs to be restarted (via the Runtime menu), variables may be lost but packages would not need to be reinstalled unless a new machine is assigned.
#
# https://research.google.com/colaboratory/faq.html
#
# Sign into colab.research.google.com and choose the Upload tab and upload this notebook.  This will automatically create a folder called "Colab Notebooks" in your Google Drive (if it does not already exist). Next upload the dataset **"fraud_data.csv"** into this "Colab Notebooks" folder by going firstly to drive.google.com.

# %% [markdown]
# ## Setup

# %% [markdown]
# The following code connects your Google Drive to this notebook. A new window will open to prompt you to allow the connection to occur.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Upon running the following cell you should see the name of this notebook and fraud_data.csv.

# %%
# !ls "/content/gdrive/My Drive/Colab Notebooks/"
# Out:
#  amazon_cells_labelled.txt
#  CapstoneProject.ipynb
#  CarDamage
# 'Copy of IOD_Lab-10_4-PySpark.ipynb'
# 'Copy of MiniProject3.ipynb'
#  fraud_data.csv
#  imdb_labelled_fixed.txt
#  IOD_Demo-9_1_2-Multi-Agent_System_with_CrewAI.ipynb
#  IOD_Demo-9_2_1-Neural_Networks_Basics.ipynb
#  IOD_Demo-9_2_2-TensorFlow_Simulator.ipynb
#  IOD_Demo-9_2_4-Keras.ipynb
#  IOD_Demo-9_2_5-Keras_CNNs.ipynb
# 'IOD_Lab-10_1 - AI Image Generation.ipynb'
# 'IOD_Lab-10_1 - SageMaker and managed services.ipynb'
#  IOD_Lab-10_2.ipynb
# 'IOD_Lab-10_3 - Answers.ipynb'
#  IOD_Lab-10_3.ipynb
#  IOD_Lab-10_3-PySpark.ipynb
# 'IOD_Lab-10_4-Datastreaming and Kafka (optional).ipynb'
#  IOD_Lab-10_4-PySpark.ipynb
# 'IOD_Lab-10_5-Datastreaming and Kafka (optional).ipynb'
# 'IOD_Lab-8_2 - NLTK spacy stemming etc .ipynb'
# 'IOD_Lab-8_3 - Sentiment_Analysis.ipynb'
# 'IOD_Lab-8_4 - Text Classification.ipynb'
# 'IOD_Lab-9_1 - Regression NN with Keras.ipynb'
#  IOD_Lab-9_2-Answers.ipynb
# 'IOD_Lab-9_2 - CNN with keras.ipynb'
#  MiniProject3.ipynb
#  ncc-1701-D.txt
#  Untitled
#  Untitled0.ipynb
#  Untitled2.ipynb
#  WebAppDraft.ipynb
#  WPP2019_PopulationBySingleAgeSex_1950-2019.csv
#  yelp_labelled.txt

# %% [markdown]
# Next download and install Kafka:

# %%
# !curl -sSOL https://downloads.apache.org/kafka/3.9.0/kafka_2.13-3.9.0.tgz
# !tar -xzf kafka_2.13-3.9.0.tgz

# %% [markdown]
# The kafka-python library will provide a Python-like interface to the Kafka platform:

# %%
# !pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.2.15-py2.py3-none-any.whl.metadata (10.0 kB)
# Downloading kafka_python-2.2.15-py2.py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.8/309.8 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.2.15

# %% [markdown]
# Finally dash will be used for interactive plotting in this notebook:

# %%
# !pip install dash
# Out:
# Collecting dash
#   Downloading dash-3.1.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from dash) (3.1.1)
# Requirement already satisfied: Werkzeug<3.2 in /usr/local/lib/python3.11/dist-packages (from dash) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from dash) (5.24.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash) (4.14.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.4.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dash) (75.2.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from Flask<3.2,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.2,>=1.0.4->dash) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Flask<3.2,>=1.0.4->dash) (3.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->dash) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->dash) (25.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (2025.7.14)
# Downloading dash-3.1.1-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 37.0 MB/s eta 0:00:00
# Downloading retrying-1.4.0-py3-none-any.whl (11 kB)
# Installing collected packages: retrying, dash
# Successfully installed dash-3.1.1 retrying-1.4.0

# %%
import time
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

from kafka import KafkaProducer
from kafka import KafkaConsumer

from dash import Dash
from dash import dcc
from dash import html
from dash.dependencies import (Input, Output)
import plotly.graph_objs as go
from plotly.subplots import make_subplots

import re
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We use the following shell command to run Zookeeper and Kafka.
#
# Apache ZooKeeper is used in distributed systems for service synchronisation, tracking the status of nodes in the Kafka cluster and maintaining a list of Kafka topics and messages.

# %%
# !./kafka_2.13-3.9.0/bin/zookeeper-server-start.sh -daemon ./kafka_2.13-3.9.0/config/zookeeper.properties
# !./kafka_2.13-3.9.0/bin/kafka-server-start.sh -daemon ./kafka_2.13-3.9.0/config/server.properties
# !echo "Waiting until zookeeper and kafka services are ready"
# !sleep 10
# Out:
# Waiting until zookeeper and kafka services are ready

# %% [markdown]
# ## Loading the dataset

# %% [markdown]
# The dataset fraud_data.csv represents credit card transactions which have been labelled as fraudulent or non-fraudulent. It is synthetically generated and is based on the dataset at https://www.kaggle.com/kartik2112/fraud-detection. Some of the features based on transactions in the past 24 hours or 6 months have been engineered from the raw data.
#
# - trans_datetime - date and time of the transaction
# - cc_num - credit card number of the customer
# - merchant - name of the merchant to which the customer is paying
# - amt: amount of the transaction in $
# - first: first name of the customer
# - last: last name of the customer
# - gender: gender of the customer
# - street, city, state: address of the customer
# - zip: zip code of the transaction
# - lat: latitude of the customer
# - long: longitude of the customer
# - city_pop: population of the city where the customer is living
# - job, age: job and age of the customer
# - num_trans_60d, num_trans_24h: number of transactions by this credit card in the past 60 days, 24 hours respectively
# - num_fraud_trans_24h: number of fraudulent transactions by this credit card in the past 24 hours
# - avg_trans_amt_60d: the average number of transactions by this credit card in the past 60 days
# - is_fraud: whether the transaction is fraud or not (1 - fraud, 0 - not fraud)

# %%
df = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/fraud_data.csv')
df.head()
# Out:
#         trans_datetime               cc_num         merchant       category  \
# 0  2019-01-01 00:14:37     2305336922781618       Harris Inc  gas_transport
# 1  2019-01-01 00:18:06  4428780983793657331        Lesch Ltd   shopping_pos
# 2  2019-01-01 00:40:50      213178850083780  Cummerata-Jones  gas_transport
# 3  2019-01-01 00:47:55     3525668150756629    Heathcote LLC   shopping_net
# 4  2019-01-01 01:02:16      376028110684021         Wolf Inc    grocery_pos
#
#    amount    firstname lastname gender                         street  \
# 0   50.79      Jeffrey     Rice      M            21447 Powell Circle
# 1   22.95      Richard   Waters      M      7683 Natasha Way Apt. 945
# 2   70.53        Shawn     King      M            31493 Garcia Summit
# 3  101.35  Christopher     Choi      M  04611 Sandra Spring Suite 059
# 4   89.11        Aaron   Murray      M      624 Hale Springs Apt. 572
#
#         city  ...      lat       lon  city_pop  \
# 0    Moulton  ...  40.6866  -92.6833      1132
# 1   Waukesha  ...  42.9993  -88.2196     95015
# 2     Athena  ...  45.8289 -118.4971      1302
# 3     Rumely  ...  46.3481  -87.0436       137
# 4  Meadville  ...  39.7795  -93.3014       964
#
#                                   job  age num_trans_60d  num_trans_24h  \
# 0                   Probation officer   58             1              6
# 1             Therapist, occupational   73             1              8
# 2                              Dealer   42             1              6
# 3                   Film/video editor   28           424              5
# 4  Tourist information centre manager   44             1              3
#
#    num_fraud_trans_24h  avg_trans_amt_60d  is_fraud
# 0                    0              50.79         0
# 1                    0              22.95         0
# 2                    0              52.48         0
# 3                    0              69.34         0
# 4                    0              66.03         0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Perform EDA
#
# **Exercise**: Perform some exploratory data analysis on the df dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96510 entries, 0 to 96509
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   trans_datetime       96510 non-null  object
#  1   cc_num               96510 non-null  int64
#  2   merchant             96510 non-null  object
#  3   category             96510 non-null  object
#  4   amount               96510 non-null  float64
#  5   firstname            96510 non-null  object
#  6   lastname             96510 non-null  object
#  7   gender               96510 non-null  object
#  8   street               96510 non-null  object
#  9   city                 96510 non-null  object
#  10  state                96510 non-null  object
#  11  zip                  96510 non-null  int64
#  12  lat                  96510 non-null  float64
#  13  lon                  96510 non-null  float64
#  14  city_pop             96510 non-null  int64
#  15  job                  96510 non-null  object
#  16  age                  96510 non-null  int64
#  17  num_trans_60d        96510 non-null  int64
#  18  num_trans_24h        96510 non-null  int64
#  19  num_fraud_trans_24h  96510 non-null  int64
#  20  avg_trans_amt_60d    96510 non-null  float64
#  21  is_fraud             96510 non-null  int64
# dtypes: float64(4), int64(8), object(10)
# memory usage: 16.2+ MB

# %%
df.describe()
# Out:
#              cc_num        amount           zip           lat           lon  \
# count  9.651000e+04  96510.000000  96510.000000  96510.000000  96510.000000
# mean   4.157534e+17    113.805738  48763.798777     38.550004    -90.236313
# std    1.306572e+18    224.213433  26904.442608      5.089822     13.863794
# min    6.041621e+10      1.000000   1257.000000     20.027100   -165.672300
# 25%    1.800385e+14     11.090000  26041.000000     34.690200    -96.786900
# 50%    3.519607e+15     51.610000  48088.000000     39.354300    -87.461600
# 75%    4.634956e+15     96.607500  72011.000000     41.940400    -80.158000
# max    4.992346e+18  11629.340000  99921.000000     66.693300    -67.950300
#
#            city_pop           age  num_trans_60d  num_trans_24h  \
# count  9.651000e+04  96510.000000   96510.000000   96510.000000
# mean   9.025761e+04     46.541913     198.859890       5.100187
# std    3.046838e+05     17.633735     100.354014       3.196524
# min    2.300000e+01     14.000000       0.000000       0.000000
# 25%    7.430000e+02     33.000000     123.000000       3.000000
# 50%    2.471000e+03     44.000000     194.000000       4.000000
# 75%    2.032800e+04     58.000000     267.000000       7.000000
# max    2.906700e+06     96.000000     557.000000      35.000000
#
#        num_fraud_trans_24h  avg_trans_amt_60d      is_fraud
# count         96510.000000       96510.000000  96510.000000
# mean              0.373599          71.689247      0.100000
# std               1.373979          37.235889      0.300002
# min               0.000000           0.000000      0.000000
# 25%               0.000000          54.670000      0.000000
# 50%               0.000000          64.210000      0.000000
# 75%               0.000000          83.880000      0.000000
# max              15.000000         913.950000      1.000000

# %%
df['category'].value_counts()
# Out:
# category
# grocery_pos       10326
# gas_transport      9726
# shopping_pos       8856
# shopping_net       8724
# home               8616
# kids_pets          7897
# entertainment      6665
# personal_care      6432
# food_dining        6287
# health_fitness     5994
# misc_pos           5568
# misc_net           5372
# grocery_net        3182
# travel             2865
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['trans_datetime', 'cc_num', 'merchant', 'category', 'amount',
#        'firstname', 'lastname', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'lon', 'city_pop', 'job', 'age', 'num_trans_60d',
#        'num_trans_24h', 'num_fraud_trans_24h', 'avg_trans_amt_60d',
#        'is_fraud'],
#       dtype='object')

# %% [markdown]
# **Question**: How balanced is this dataset?

# %%
# ANSWER
df['is_fraud'].value_counts()
# Out:
# is_fraud
# 0    86859
# 1     9651
# Name: count, dtype: int64

# %% [markdown]
# 90% of data is non-fraud

# %% [markdown]
# Correlation matrix:

# %%
df_numerical = df[['amount', 'lat', 'lon', 'city_pop', 'age', 'num_trans_60d',
                   'num_trans_24h', 'num_fraud_trans_24h', 'avg_trans_amt_60d',
                   'is_fraud']]

# %%
colormap = plt.cm.coolwarm
plt.figure(figsize = (10, 10))
plt.title('Pearson Correlation of Features', size = 15)
sns.heatmap(df_numerical.astype(float).corr(),
            linewidths = 0.1,
            vmax = 1.0,
            square = True,
            cmap = colormap,
            linecolor = 'white',
            annot = True)
plt.show()

# %% [markdown]
# We see that amount, num_trans_60d, num_fraud_trans_24h, and num_trans_avg_amt_60d have the strongest correlation with the target variable is_fraud.

# %% [markdown]
# Since the dataset is large, we sample 1000 rows to obtain a pairplot.

# %%
sns.pairplot(df_numerical.sample(1000, random_state=0))
plt.show()

# %% [markdown]
# ## Create topics
#
# Kafka records are stored in *topics* which can be thought of as data feeds that one can subscribe to.
#
# We shall create two topics to the Kafka platform.
#
# - One with customer information (called *customerinfo*)
# - One with predictors that can be used for a fraud prediction algorithm (called *features*)

# %%
# !./kafka_2.13-3.9.0/bin/kafka-topics.sh --create --bootstrap-server 127.0.0.1:9092 --replication-factor 1 --partitions 2 --topic customerinfo
# !./kafka_2.13-3.9.0/bin/kafka-topics.sh --create --bootstrap-server 127.0.0.1:9092 --replication-factor 1 --partitions 1 --topic features
# Out:
# Created topic customerinfo.
# Created topic features.

# %% [markdown]
# View their details:

# %%
# !./kafka_2.13-3.9.0/bin/kafka-topics.sh --describe --bootstrap-server 127.0.0.1:9092 --topic customerinfo
# !./kafka_2.13-3.9.0/bin/kafka-topics.sh --describe --bootstrap-server 127.0.0.1:9092 --topic features
# Out:
# Topic: customerinfo	TopicId: CatGjifTRpCj8YzeWW0v1w	PartitionCount: 2	ReplicationFactor: 1	Configs:
# 	Topic: customerinfo	Partition: 0	Leader: 0	Replicas: 0	Isr: 0	Elr: N/A	LastKnownElr: N/A
# 	Topic: customerinfo	Partition: 1	Leader: 0	Replicas: 0	Isr: 0	Elr: N/A	LastKnownElr: N/A
# Topic: features	TopicId: yqVoWJkKQparNo3VB4zMIQ	PartitionCount: 1	ReplicationFactor: 1	Configs:
# 	Topic: features	Partition: 0	Leader: 0	Replicas: 0	Isr: 0	Elr: N/A	LastKnownElr: N/A

# %% [markdown]
# Next we create the records for these topics. The records need to be a list of key-value pairs. Here we will make the key the datetime (timestamp) of the transaction.

# %%
timestamps = list(df['trans_datetime'][90000:].to_csv(index=False).split("\n"))
X_kafka = list(df.drop(['trans_datetime'],axis=1)[90000:].to_csv(index=False).split("\n"))

# %%
predictors = ['amount', 'num_trans_60d', 'num_fraud_trans_24h', 'avg_trans_amt_60d']
featuredata = list(df[predictors + ['is_fraud']][90000:].to_csv(index=False).split("\n"))

# %%
X_kafka
# Out:
# ['cc_num,merchant,category,amount,firstname,lastname,gender,street,city,state,zip,lat,lon,city_pop,job,age,num_trans_60d,num_trans_24h,num_fraud_trans_24h,avg_trans_amt_60d,is_fraud',
#  '377834944388609,Kuhic LLC,shopping_net,1061.02,Michael,Jackson,M,539 Underwood Divide,Pea Ridge,AR,72751,36.4539,-94.118,6434,Product designer,53,56,5,5,68.13,1',
#  '639030014711,"Schumm, McLaughlin and Carter",food_dining,62.68,Stephen,Lopez,M,696 Matthew Ford Suite 157,Olmsted,IL,62970,37.1935,-89.0933,639,Mechanical engineer,38,111,5,0,92.62,0',
#  '4155021259183870,Pollich LLC,home,59.16,Renee,Parrish,F,174 Jennifer Meadow Apt. 467,Mountain Park,OK,73559,34.7032,-98.9591,540,Research scientist (life sciences),37,215,12,0,61.68,0',
#  '4874017206859125,"Mueller, Gerhold and Mueller",health_fitness,93.83,Lauren,Williams,F,065 Jones Stravenue,Lake Oswego,OR,97034,45.4093,-122.6847,42817,Planning and development surveyor,39,141,9,0,94.91,0',
#  '3513618443244549,Streich Ltd,home,8.62,Amber,Perez,F,954 Reyes Ways,Fulton,SD,57340,43.7588,-97.8712,355,Financial adviser,65,224,14,0,70.26,0',
#  '571465035400,Brown-Greenholt,entertainment,73.3,Louis,Fisher,M,45654 Hess Rest,Fort Washakie,WY,82514,43.0048,-108.8964,1645,Freight forwarder,45,217,17,0,92.72,0',
#  '60416207185,Schumm PLC,shopping_net,9.92,Mary,Diaz,F,9886 Anita Drive,Fort Washakie,WY,82514,43.0048,-108.8964,1645,Information systems manager,35,188,7,0,85.84,0',
#  '377834944388609,Upton PLC,entertainment,409.2,Michael,Jackson,M,539 Underwood Divide,Pea Ridge,AR,72751,36.4539,-94.118,6434,Product designer,53,56,6,6,68.13,1',
#  '373043435942726,"Lowe, Dietrich and Erdman",kids_pets,53.29,Vincent,Richards,M,2064 Tyler Fork,Beasley,TX,77417,29.479,-95.9681,2457,Trading standards officer,40,107,4,0,99.47,0',
#  '36913587729122,Gaylord-Powlowski,home,1.17,Ana,Mccormick,F,4503 Patricia Route,Meridian,ID,83646,43.6498,-116.4306,84106,Intelligence analyst,50,276,12,0,108.88,0',
#  '372246459334925,"Romaguera, Wehner and Tromp",kids_pets,21.46,Rick,Martinez,M,062 Poole Hollow Apt. 815,Deadwood,SD,57732,44.3566,-103.6999,1979,Multimedia programmer,51,158,9,0,58.25,0',
Jason,Johnson,M,5942 Thomas Park,Craig,AK,99921,55.4732,-133.1171,1920,Commissioning editor,23,1,3,3,9.16,1',
#  '3588001568691267,Predovic Inc,shopping_net,1061.37,Jason,Johnson,M,5942 Thomas Park,Craig,AK,99921,55.4732,-133.1171,1920,Commissioning editor,23,1,4,4,9.16,1',
#  '3588001568691267,"Altenwerth, Cartwright and Koss",shopping_net,1008.38,Jason,Johnson,M,5942 Thomas Park,Craig,AK,99921,55.4732,-133.1171,1920,Commissioning editor,23,1,5,5,9.16,1',
#  '30266994494236,"Quitzon, Green and Bashirian",shopping_pos,918.2,Sarah,Foster,F,77872 Andrea Glen Apt. 543,Ford,VA,23850,37.1349,-77.7364,1051,Chief Operating Officer,44,182,2,2,71.83,1',
#  '370348764075623,Torphy-Kertzmann,health_fitness,14.79,Christopher,Gomez,M,950 Dunn Squares,Tickfaw,LA,70466,30.5668,-90.482,8512,"Accountant, chartered public finance",69,119,4,0,75.18,0',
#  '3588001568691267,"Romaguera, Cruickshank and Greenholt",shopping_net,926.72,Jason,Johnson,M,5942 Thomas Park,Craig,AK,99921,55.4732,-133.1171,1920,Commissioning editor,23,1,6,6,9.16,1',
#  '3588001568691267,Goyette Inc,shopping_net,990.84,Jason,Johnson,M,5942 Thomas Park,Craig,AK,99921,55.4732,-133.1171,1920,Commissioning editor,23,1,7,7,9.16,1',
#  '30376238035123,"Roberts, Daniel and Macejkovic",kids_pets,4.54,Cynthia,Davis,F,7177 Steven Forges,Sixes,OR,97476,42.825,-124.4409,217,Retail merchandiser,92,109,2,0,54.53,0',
#  '4874006077381178,"Reichert, Rowe and Mraz",shopping_net,91.48,Patricia,Russell,F,89297 Wilson Green Suite 601,Moscow,IA,52760,41.5646,-91.0859,533,Chief Technology Officer,31,71,1,0,48.63,0',
#  '3588001568691267,Barrows PLC,shopping_pos,1118.24,Jason,Johnson,M,5942 Thomas Park,Craig,AK,99921,55.4732,-133.1171,1920,Commissioning editor,23,1,8,8,9.16,1',
#  '3560797065840735,Kerluke-Abshire,shopping_net,3.0,Janet,Turner,F,0925 Lang Extensions,Shields,ND,58569,46.1838,-101.2589,77,Film/video editor,31,370,14,0,54.61,0',
#  '3588001568691267,Beier-Hyatt,shopping_pos,1183.93,Jason,Johnson,M,5942 Thomas Park,Craig,AK,99921,55.4732,-133.1171,1920,Commissioning editor,23,1,9,9,9.16,1',
#  '377834944388609,Kuhic LLC,shopping_net,993.4,Michael,Jackson,M,539 Underwood Divide,Pea Ridge,AR,72751,36.4539,-94.118,6434,Product designer,53,62,7,2,113.05,1',
#  '4904681492230012,"Douglas, Schneider and Turner",shopping_pos,8.95,Lisa,Lowe,F,574 David Locks Suite 207,Cottekill,NY,12419,41.8467,-74.1038,722,Comptroller,30,302,15,0,66.29,0',
#  '4687263141103,Flatley Group,misc_pos,2.32,Sarah,Cross,F,273 Phillip Throughway,Bigelow,MN,56117,43.5336,-95.6515,399,Economist,44,47,3,0,43.28,0',
#  '2254917871818484,Waelchi-Wolf,kids_pets,14.15,Margaret,Gibson,F,382 Williams Stream Suite 197,Scotland,MD,20687,38.0828,-76.3477,313,Insurance underwriter,45,280,12,0,51.25,0',
#  '30501624614310,Lemke-Gutmann,shopping_net,3.47,Amanda,Smith,F,180 Graves Shore,Scotia,SC,29939,32.6786,-81.2455,302,Magazine features editor,48,221,5,0,62.84,0',
#  '30238755902988,Kutch LLC,gas_transport,50.44,Danielle,Yu,F,5395 Colon Burgs Suite 037,Thrall,TX,76578,30.592,-97.2893,1766,Press sub,45,316,9,0,57.33,0',
#  '344342339068828,Berge LLC,gas_transport,78.42,Ruth,Fuller,F,37732 Joe Courts Apt. 752,Darien,GA,31305,31.3826,-81.4312,5989,Tax adviser,54,191,6,0,81.87,0',
#  '6011148190095209,VonRueden Group,grocery_net,106.45,Terri,Bailey,F,508 Erin Mount,Daly City,CA,94015,37.6787,-122.478,107941,"Buyer, industrial",29,177,4,0,105.84,0',
#  '3588001568691267,Kutch and Sons,grocery_pos,333.42,Jason,Johnson,M,5942 Thomas Park,Craig,AK,99921,55.4732,-133.1171,1920,Commissioning editor,23
#  '30143713661454,Pouros-Haag,shopping_pos,9.0,Nicholas,Thornton,M,5270 Megan Burg Suite 756,Halma,MN,56729,48.6669,-96.5969,140,"Embryologist, clinical",79,109,3,0,67.34,0',
#  '343746486082492,"Christiansen, Goyette and Schamberger",gas_transport,63.0,Jeffrey,Munoz,M,836 Stephanie Union,Cedar,MI,49621,44.8605,-85.8138,3096,"Social research officer, government",45,180,4,0,46.81,0',
#  '3533800906065217,"Eichmann, Bogan and Rodriguez",gas_transport,63.95,Amber,Thornton,F,840 Werner Lock Apt. 852,Campbell,NE,68932,40.2967,-98.737,493,"Surveyor, minerals",80,173,4,0,55.67,0',
#  '213107169859697,McCullough LLC,misc_pos,328.8,Megan,Fernandez,F,77127 Paul Station Apt. 495,Woods Cross,UT,84087,40.8874,-111.9027,13983,Insurance broker,41,59,8,0,86.46,0',
#  '4681699462969,Kerluke PLC,misc_net,9.58,Joseph,Gonzalez,M,319 Wendy Fort Suite 179,Murfreesboro,TN,37132,35.8596,-86.421,158701,"Journalist, newspaper",43,268,9,0,53.02,0',
#  '4900628639996,Kemmer-Reinger,grocery_net,46.14,Michael,Johnson,M,094 Owens Underpass,Norwalk,CA,90650,33.9056,-118.0818,105549,Firefighter,47,294,7,0,56.1,0',
#  '6011542681743618,Rau and Sons,grocery_pos,87.15,Emily,Hall,F,8851 Reese Neck,Basye,VA,22810,38.8089,-78.7776,863,"Engineer, mining",48,223,10,0,50.53,0',
#  '213161293389774,Mohr Inc,shopping_pos,8.03,Catherine,Weber,F,74890 Rodriguez Springs Apt. 540,West Henrietta,NY,14586,43.0397,-77.6871,10256,"Teacher, primary school",52,188,8,0,63.97,0',
#  '180047222886866,Smitham-Schiller,grocery_net,44.83,Christine,Shaffer,F,14017 Thomas Plaza,Loami,IL,62661,39.6704,-89.8588,1213,English as a foreign language teacher,30,60,4,0,67.86,0',
#  '4666314527820883145,Kunze Inc,grocery_pos,109.92,Guy,Thompson,M,5812 Ramos Oval Suite 598,Ravenna,NE,68869,41.0233,-98.9041,2202,"Solicitor, Scotland",46,61,4,0,82.95,0',
#  '4841313716651064,Bauch-Raynor,grocery_pos,95.78,Omar,Gay,M,2161 Blankenship Freeway,West Hartford,VT,5084,43.7185,-72.4439,140,"Development worker, community",31,229,6,0,96.19,0',
#  '3567879740649740,Kerluke PLC,misc_net,915.79,Tanya,Williams,F,566 Megan Well,Brownville,NY,13615,44.0577,-76.0196,1271,"Producer, radio",62,217,12,0,67.91,0',
#  '4457732997086323466,DuBuque LLC,grocery_pos,114.7,Stanley,Mayo,M,3433 Jones Branch,Fiddletown,CA,95629,38.5234,-120.6763,832,Immigration officer,34,249,10,0,92.58,0',
#  '3543591270174051,Ruecker Group,misc_net,15.64,Margaret,Lam,F,6911 Nicholas Keys Apt. 237,Armagh,PA,15920,40.4603,-79.0097,922,Early years teacher,48,293,8,0,42.75,0',
#  '4683638447911,Skiles-Ankunding,grocery_net,51.63,Daniel,Boyd,M,8925 Nicholas Points,Egan,LA,70531,30.251,-92.5002,1261,Broadcast presenter,48,217,11,0,92.49,0',
#  '4412720572684931,Mante Group,misc_net,905.63,Richard,Marshall,M,295 Page Creek Suite 181,Greenbush,VA,23357,37.7681,-75.6664,776,Psychiatrist,71,56,4,4,48.45,1',
#  '3564182536169293,Boyer PLC,shopping_net,1073.81,Brenda,Johnson,F,56160 Nicholas Isle,Norwich,OH,43767,39.9934,-81.8024,1443,Research scientist (medical),59,130,7,7,78.95,1',
#  ...]

# %%
featuredata
# Out:
# ['amount,num_trans_60d,num_fraud_trans_24h,avg_trans_amt_60d,is_fraud',
#  '1061.02,56,5,68.13,1',
#  '62.68,111,0,92.62,0',
#  '59.16,215,0,61.68,0',
#  '93.83,141,0,94.91,0',
#  '8.62,224,0,70.26,0',
#  '73.3,217,0,92.72,0',
#  '9.92,188,0,85.84,0',
#  '409.2,56,6,68.13,1',
#  '53.29,107,0,99.47,0',
#  '1.17,276,0,108.88,0',
#  '21.46,158,0,58.25,0',
#  '38.56,282,0,68.59,0',
#  '2.24,249,0,51.68,0',
#  '35.1,337,0,90.32,0',
#  '7.95,232,0,62.61,0',
#  '244.39,336,0,79.15,0',
#  '43.25,177,0,90.78,0',
#  '6.3,118,0,55.08,0',
#  '3.11,283,0,43.19,0',
#  '79.71,265,0,47.38,0',
#  '79.34,229,0,95.37,0',
#  '9.3,244,0,43.38,0',
#  '54.6,152,0,51.05,0',
#  '6.38,241,0,49.52,0',
#  '436.63,271,0,50.39,0',
#  '2.48,280,0,54.8,0',
#  '77.24,215,0,94.13,0',
#  '66.93,65,0,87.91,0',
#  '69.43,112,0,99.0,0',
#  '9.16,1,0,9.16,1',
#  '71.88,289,0,53.63,0',
#  '84.37,155,0,37.36,0',
#  '53.54,230,0,79.18,0',
#  '6.71,167,0,55.95,0',
#  '183.99,58,0,55.73,0',
#  '72.07,185,0,90.52,0',
#  '5.48,188,0,61.51,0',
#  '26.63,164,0,53.14,0',
#  '104.55,111,0,124.15,0',
#  '64.24,261,0,51.36,0',
#  '102.9,59,0,66.1,0',
#  '49.1,108,0,77.65,0',
#  '116.6,312,0,46.94,0',
#  '131.93,208,0,65.4,0',
#  '10.75,62,6,113.05,1',
#  '93.07,210,0,90.54,0',
#  '106.38,60,0,66.48,0',
#  '11.72,122,0,49.28,0',
#  '324.22,62,6,113.05,1',
#  '64.4,53,0,44.14,0',
#  '66.86,170,0,55.24,0',
#  '395.48,104,0,99.81,0',
#  '57.74,58,0,56.9,0',
#  '81.74,171,0,88.27,0',
#  '74.88,325,0,47.49,0',
#  '5.79,236,0,59.22,0',
#  '27.0,303,0,43.6,0',
#  '1.59,173,0,45.86,0',
#  '170.63,118,0,64.01,0',
#  '115.87,54,0,39.97,0',
#  '66.2,121,0,52.1,0',
#  '9.92,215,0,51.4,0',
#  '92.92,261,0,51.36,0',
#  '64.62,228,0,52.78,0',
#  '4.78,231,0,69.45,0',
#  '111.65,338,0,70.04,0',
#  '220.62,226,0,96.94,0',
#  '207.98,211,0,103.22,0',
#  '37.51,363,0,71.67,0',
#  '67.11,166,0,52.27,0',
#  '8.06,116,0,59.9,0',
#  '16.09,111,0,76.92,0',
#  '61.88,240,0,51.5,0',
#  '69.4,117,0,52.97,0',
#  '103.38,66,0,87.88,0',
#  '72.17,113,0,102.71,0',
#  '66.4,294,0,85.32,0',
#  '33.45,337,0,65.73,0',
#  '1.35,328,0,44.56,0',
#  '5.71,286,0,92.26,0',
#  '173.93,82,0,142.17,0',
#  '19.94,352,0,54.62,0',
#  '342.31,348,0,84.23,0',
#  '4.66,267,0,47.83,0',
#  '205.76,278,0,78.5,0',
#  '9.02,57,0,81.56,0',
#  '73.87,231,0,53.23,0',
#  '3.49,320,0,49.27,0',
#  '1.52,219,0,61.8,0',
#  '91.46,75,0,67.31,0',
#  '1.8,368,0,79.63,0',
#  '49.92,296,0,94.27,0',
#  '74.04,228,0,92.56,0',
#  '37.77,266,0,97.48,0',
#  '140.56,112,0,270.58,0',
#  '120.98,119,0,48.72,0',
#  '64.31,170,0,69.62,0',
#  '172.58,155,0,56.04,0',
#  '505.24,242,0,94.98,0',
#  '55.43,122,0,61.3,0',
#  '41.42,95,0,83.96,0',
#  '5.08,306,0,67.76,0',
#  '36.37,113,0,58.69,0',
#  '1.67,167,0,55.45,0',
#  '7.77,178,0,40.77,0',
#  '1.6,122,0,61.3,0',
#  '4.17,313,0,57.61,0',
#  '8.28,245,0,47.31,0',
#  '26.35,352,0,54.62,0',
#  '74.15,181,0,96.66,0',
#  '31.84,350,0,79.41,0',
#  '26.53,296,0,76.99,0',
#  '1.17,230,0,61.45,0',
#  '123.17,46,0,67.7,0',
#  '1.47,221,0,42.92,0',
#  '28.5,244,0,55.57,0',
#  '14.52,178,0,40.77,0',
#  '52.78,231,0,69.45,0',
#  '14.77,218,0,49.94,0',
#  '1.79,68,0,54.36,0',
#  '29.33,275,0,52.42,0',
#  '5.97,174,0,68.98,0',
#  '11.38,54,0,62.85,0',
#  '196.19,398,0,69.66,0',
#  '36.28,349,0,89.88,0',
#  '3.49,108,0,56.49,0',
#  '3.09,165,0,60.27,0',
#  '7.49,228,0,55.39,0',
#  '139.5,156,0,58.33,0',
#  '7.71,335,0,52.02,0',
#  '62.13,100,0,82.17,0',
#  '20.68,362,0,90.58,0',
#  '52.09,263,0,47.34,0',
#  '36.78,154,0,97.65,0',
#  '97.05,52,0,46.2,0',
#  '78.34,117,0,66.83,0',
#  '2.73,228,0,55.39,0',
#  '78.67,113,0,73.72,0',
#  '2.19,66,0,49.92,0',
#  '128.23,187,0,70.17,0',
#  '15.81,297,0,57.08,0',
#  '56.09,165,0,78.67,0',
#  '71.0,215,0,83.64,0',
#  '21.09,268,0,43.18,0',
#  '33.53,178,0,106.03,0',
#  '29.56,106,0,59.28,0',
#  '37.17,174,0,51.1,0',
#  '15.06,352,0,54.62,0',
#  '75.04,220,0,95.62,0',
#  '87.35,110,0,105.37,0',
#  '25.39,231,0,69.45,0',
#  '7.01,320,0,49.27,0',
#  '11.78,288,0,83.86,0',
#  '9.99,119,0,47.82,0',
#  '82.77,167,0,55.95,0',
#  '199.7,158,0,81.86,0',
#  '6.14,318,0,67.97,0',
#  '78.45,318,0,67.97,0',
#  '3.21,55,0,56.62,0',
#  '72.05,239,0,90.38,0',
#  '235.16,160,0,57.99,0',
#  '3.08,370,0,70.56,0',
#  '5.08,217,0,57.55,0',
#  '34.25,273,0,52.41,0',
#  '14.05,178,0,56.33,0',
#  '33.52,224,0,54.31,0',
#  '6.13,296,0,54.38,0',
#  '42.12,172,0,60.4,0',
#  '6.83,329,0,86.52,0',
#  '745.05,1,1,9.16,1',
#  '603.08,182,0,71.83,1',
#  '79.6,253,0,43.19,0',
#  '1318.89,1,2,9.16,1',
#  '5.23,155,0,37.36,0',
#  '12.15,156,0,59.88,0',
#  '9.31,221,0,42.92,0',
#  '223.49,182,1,71.83,1',
#  '984.28,1,3,9.16,1',
#  '1061.37,1,4,9.16,1',
#  '1008.38,1,5,9.16,1',
#  '918.2,182,2,71.83,1',
#  '14.79,119,0,75.18,0',
#  '926.72,1,6,9.16,1',
#  '990.84,1,7,9.16,1',
#  '4.54,109,0,54.53,0',
#  '91.48,71,0,48.63,0',
#  '1118.24,1,8,9.16,1',
#  '3.0,370,0,54.61,0',
#  '1183.93,1,9,9.16,1',
#  '993.4,62,2,113.05,1',
#  '8.95,302,0,66.29,0',
#  '2.32,47,0,43.28,0',
#  '14.15,280,0,51.25,0',
#  '3.47,221,0,62.84,0',
#  '50.44,316,0,57.33,0',
#  '78.42,191,0,81.87,0',
#  '106.45,177,0,105.84,0',
#  '333.42,10,9,831.59,1',
#  '51.88,157,0,56.87,0',
#  '298.76,10,10,831.59,1',
#  '79.06,114,0,96.83,0',
#  '140.63,242,0,59.02,0',
#  '41.51,159,0,44.99,0',
#  '50.09,177,0,50.84,0',
#  '219.18,288,0,90.9,0',
#  '40.94,243,0,96.12,0',
#  '43.22,219,0,61.93,0',
#  '4.39,243,0,66.52,0',
#  '134.65,196,0,59.05,0',
#  '406.33,53,0,64.04,0',
#  '39.76,169,0,60.93,0',
#  '9.0,109,0,67.34,0',
#  '63.0,180,0,46.81,0',
#  '63.95,173,0,55.67,0',
#  '328.8,59,0,86.46,0',
#  '9.58,268,0,53.02,0',
#  '46.14,294,0,56.1,0',
#  '87.15,223,0,50.53,0',
#  '8.03,188,0,63.97,0',
#  '44.83,60,0,67.86,0',
#  '109.92,61,0,82.95,0',
#  '95.78,229,0,96.19,0',
#  '915.79,217,0,67.91,0',
#  '114.7,249,0,92.58,0',
#  '15.64,293,0,42.75,0',
#  '51.63,217,0,92.49,0',
#  '31.01,222,0,59.22,0',
#  '40.02,287,0,82.7,0',
#  '56.36,229,0,59.97,0',
#  '101.21,119,0,57.27,0',
#  '63.48,297,0,55.0,0',
#  '1.66,178,0,66.27,0',
#  '86.73,218,0,105.18,0',
#  '48.73,223,0,75.13,0',
#  '3.48,122,0,63.98,0',
#  '80.22,116,0,58.1,0',
#  '44.38,219,0,61.93,0',
#  '29.23,170,0,125.58,0',
#  '73.91,175,0,83.42,0',
#  '39.75,177,0,105.84,0',
#  '20.74,185,0,91.76,0',
#  '5.22,112,0,67.88,0',
#  '65.63,333,0,95.35,0',
#  '62.32,76,0,67.63,0',
#  '69.02,326,0,60.76,0',
#  '7.14,224,0,62.65,0',
#  '17.86,207,0,56.12,0',
#  '40.46,293,0,50.82,0',
#  '60.92,346,0,68.54,0',
#  '39.33,237,0,60.19,0',
#  '2.22,339,0,51.85,0',
#  '38.21,361,0,53.23,0',
#  '110.16,98,0,82.89,0',
#  '58.94,227,0,62.7,0',
#  '101.65,107,0,69.3,0',
#  '2.85,180,0,111.68,0',
#  '68.39,261,0,61.14,0',
#  '75.67,177,0,41.31,0',
#  '68.51,124,0,49.94,0',
#  '115.73,213,0,103.87,0',
#  '79.43,226,0,55.01,0',
#  '70.78,220,0,99.47,0',
#  '19.11,168,0,44.19,0',
#  '188.02,230,0,57.76,0',
#  '4.21,299,0,57.68,0',
#  '150.45,205,0,64.59,0',
#  '10.88,129,0,48.47,0',
#  '13.92,54,0,50.89,0',
#  '119.46,115,0,73.47,0',
#  '9.23,161,0,50.49,0',
#  '6.06,336,0,40.07,0',
#  '3.25,215,0,72.41,0',
#  '76.09,52,0,93.25,0',
#  '96.44,119,0,65.0,0',
#  '3.27,346,0,68.54,0',
#  '16.49,153,0,56.43,0',
#  '107.34,275,0,63.4,0',
#  '66.49,279,0,78.16,0',
#  '61.86,213,0,96.73,0',
#  '33.88,327,0,54.35,0',
#  '63.07,337,0,79.97,0',
#  '75.11,100,0,55.35,0',
#  '80.77,144,0,89.54,0',
#  '75.21,215,0,72.41,0',
#  '85.73,250,0,50.26,0',
#  '5.16,220,0,50.61,0',
#  '49.46,247,0,55.39,0',
#  '43.57,233,0,47.06,0',
#  '25.66,117,0,70.95,0',
#  '12.11,238,0,59.32,0',
#  '5.45,99,0,50.21,0',
#  '36.87,344,0,69.18,0',
#  '72.67,243,0,96.12,0',
#  '5.82,307,0,67.82,0',
#  '194.69,243,0,66.52,0',
#  '71.0,323,0,49.46,0',
#  '67.2,231,0,99.82,0',
#  '23.24,326,0,60.76,0',
#  '8.18,361,0,53.23,0',
#  '2.04,186,0,50.79,0',
#  '39.68,272,0,82.87,0',
#  '4.39,273,0,51.11,0',
#  '6.16,160,0,57.25,0',
#  '72.35,333,0,95.35,0',
#  '190.76,128,0,68.19,0',
#  '35.86,328,0,77.56,0',
#  '147.33,227,0,62.7,0',
#  '129.04,107,0,67.38,0',
#  '90.2,209,0,64.2,0',
#  '128.46,284,0,58.6,0',
#  '59.96,168,0,57.4,0',
#  '65.72,111,0,54.8,0',
#  '34.97,245,0,47.81,0',
#  '103.01,56,0,66.86,0',
#  '62.45,398,0,66.14,0',
#  '60.19,113,0,67.15,0',
#  '30.92,209,0,77.86,0',
#  '23.79,288,0,63.51,0',
#  '68.91,163,0,50.51,0',
#  '14.55,49,0,128.19,0',
#  '72.56,225,0,89.84,0',
#  '12.02,107,0,58.88,0',
#  '5.75,287,0,82.7,0',
#  '113.64,115,0,70.89,0',
#  '29.01,76,0,84.74,0',
#  '9.54,128,0,79.93,0',
#  '37.39,328,0,77.56,0',
#  '104.13,60,0,34.5,0',
#  '2.54,368,0,78.92,0',
#  '3.15,307,0,67.82,0',
#  '2.57,337,0,79.97,0',
#  '73.58,374,0,92.73,0',
#  '5.33,191,0,47.03,0',
#  '67.17,235,0,69.84,0',
#  '5.3,327,0,56.98,0',
#  '9.0,111,0,42.13,0',
#  '9.35,168,0,44.19,0',
#  '81.23,182,0,102.94,0',
#  '40.74,75,0,122.14,0',
#  '36.93,346,0,68.54,0',
#  '7.13,115,0,59.66,0',
#  '14.16,168,0,55.92,0',
#  '43.09,191,0,47.03,0',
#  '12.68,269,0,61.36,0',
#  '1.15,284,0,58.6,0',
#  '50.88,120,0,78.63,0',
#  '40.46,227,0,62.7,0',
#  '881.12,10,2,831.59,1',
#  '40.92,49,0,52.33,0',
#  '71.02,107,0,69.3,0',
#  '171.63,213,0,96.73,0',
#  '781.06,10,3,831.59,1',
#  '7.96,263,0,80.67,0',
#  '88.46,231,0,64.21,0',
#  '64.77,52,0,93.25,0',
#  '75.52,205,0,58.56,0',
#  '124.87,57,0,55.69,0',
#  '50.7,168,0,96.21,0',
#  '54.13,156,0,75.28,0',
#  '84.93,182,0,82.97,0',
#  '71.56,275,0,67.92,0',
#  '9.79,273,0,61.16,1',
#  '5.31,124,0,50.51,0',
#  '86.08,62,0,53.08,0',
#  '7.64,56,0,53.47,0',
#  '179.46,287,0,104.5,0',
#  '37.49,275,0,48.53,0',
#  '73.22,170,0,125.29,0',
#  '109.93,188,0,96.78,0',
#  '13.69,366,0,47.93,1',
#  '2.87,116,0,63.17,0',
#  '72.72,188,0,46.21,0',
#  '9.22,267,0,47.6,0',
#  '71.94,170,0,78.02,0',
#  '107.31,109,0,106.57,0',
#  '6.02,182,0,82.97,0',
#  '213.02,117,0,106.19,0',
#  '101.19,306,0,72.89,0',
#  '56.53,164,0,52.26,0',
#  '80.03,59,0,63.48,0',
#  '73.27,294,0,82.56,0',
#  '5.97,283,0,81.59,0',
#  '128.59,57,0,73.49,0',
#  '13.1,56,0,62.81,0',
#  '2.92,220,0,56.71,0',
#  '69.66,251,0,60.5,0',
#  '2.48,55,0,53.67,0',
#  '436.8,363,0,91.16,0',
#  '107.09,119,0,61.7,0',
#  '81.34,149,0,69.24,0',
#  '44.46,229,0,58.48,0',
#  '4.45,226,0,78.25,0',
#  '65.76,223,0,49.9,0',
#  '77.97,252,0,62.13,0',
#  '93.0,224,0,90.83,0',
#  '14.23,152,0,79.72,0',
#  '24.38,213,0,96.8,0',
#  '90.12,208,0,86.94,0',
#  '76.87,62,0,86.12,0',
#  '75.15,275,0,67.92,0',
#  '89.45,186,0,42.97,0',
#  '59.5,153,0,61.51,0',
#  '56.43,230,0,55.14,0',
#  '75.39,106,0,89.7,0',
#  '107.16,116,0,78.71,0',
#  '62.44,49,0,63.39,0',
#  '26.83,168,0,80.71,0',
#  '91.99,110,0,63.07,0',
#  '71.43,230,0,90.43,0',
#  '62.57,183,0,72.69,0',
#  '72.5,53,0,67.24,0',
#  '82.73,151,0,63.14,0',
#  '706.46,252,0,48.48,0',
#  '44.12,104,0,66.4,0',
#  '70.48,180,0,41.21,0',
#  '153.48,238,0,70.17,0',
#  '92.53,227,0,54.15,0',
#  '8.03,189,0,60.6,0',
#  '51.06,106,0,89.7,0',
#  '202.35,355,0,85.62,0',
#  '57.08,324,0,57.22,0',
#  '63.22,351,0,53.91,0',
#  '50.63,180,0,50.55,0',
#  '4.56,51,0,54.14,0',
#  '37.07,65,0,88.16,0',
#  '71.84,119,0,61.7,0',
#  '67.9,214,0,89.92,0',
#  '5.67,356,0,78.35,0',
#  '25.53,119,0,46.16,0',
#  '27.21,227,0,54.15,0',
#  '6.64,169,0,59.76,0',
#  '54.4,58,0,59.5,0',
#  '6.25,220,0,56.71,0',
#  '2.6,103,0,47.37,0',
#  '67.89,230,0,90.43,0',
#  '8.0,158,0,52.16,0',
#  '47.77,215,0,59.66,0',
#  '4.41,284,0,46.67,0',
#  '4.78,326,0,47.96,0',
#  '7.54,238,0,52.39,0',
#  '6.14,189,0,54.5,0',
#  '244.56,112,0,84.49,0',
#  '38.6,397,0,66.21,0',
#  '38.22,254,0,54.93,0',
#  '9.35,268,0,80.22,0',
#  '11.55,119,0,46.16,0',
#  '82.16,109,0,102.79,0',
#  '86.33,222,0,51.23,0',
#  '23.09,290,0,81.94,0',
#  '8.88,254,0,54.93,0',
#  '8.39,284,0,46.67,0',
#  '40.49,174,0,53.16,0',
#  '21.07,272,0,67.17,0',
#  '26.82,293,0,80.81,0',
#  '138.45,231,0,52.62,0',
#  '3.33,189,0,45.06,0',
#  '15.16,117,0,56.03,0',
#  '5.16,348,0,69.21,0',
#  '4.71,277,0,52.58,0',
#  '129.62,238,0,60.48,0',
#  '1.16,248,0,54.07,0',
#  '33.85,117,0,56.03,0',
#  '184.38,38,0,54.49,0',
#  '30.7,306,0,43.67,0',
#  '30.28,248,0,54.07,0',
#  '38.12,275,0,48.53,0',
#  '5.41,55,0,72.79,0',
#  '149.9,276,0,102.69,0',
#  '120.4,174,0,72.8,0',
#  '3.08,125,0,67.48,0',
#  '125.95,240,0,59.98,0',
#  '3.65,210,0,50.97,0',
#  '6.21,123,0,58.33,0',
#  '5.86,334,0,60.4,0',
#  '151.68,220,0,56.71,0',
#  '109.03,238,0,85.6,0',
#  '123.38,187,0,57.05,0',
#  '21.35,290,0,81.94,0',
#  '57.04,237,0,63.64,0',
#  '5.55,276,0,52.4,0',
#  '25.99,330,0,77.81,0',
#  '26.59,397,0,66.21,0',
#  '115.74,268,0,80.22,0',
#  '8.62,218,0,70.17,0',
#  '580.77,171,0,77.17,0',
#  '9.87,103,0,35.26,0',
#  '244.68,63,0,116.6,0',
#  '2.93,272,0,53.07,0',
#  '11.98,167,0,54.28,0',
#  '68.64,234,0,94.01,0',
#  '5.47,51,0,60.23,0',
#  '88.18,229,0,58.48,0',
#  '51.19,153,0,69.53,0',
#  '30.71,335,0,40.17,0',
#  '52.97,55,0,62.18,0',
#  '6.61,326,0,47.96,0',
#  '5.65,155,0,62.6,0',
#  '71.93,247,0,95.57,0',
#  '12.39,121,0,97.79,0',
#  '7.73,220,0,55.04,0',
#  '59.78,117,0,74.43,0',
#  '3.45,103,0,49.68,0',
#  '37.16,73,0,47.04,0',
#  '271.9,397,0,66.21,0',
#  '84.43,120,0,92.1,0',
#  '959.59,273,1,61.16,1',
#  '103.12,129,0,71.76,0',
#  '106.73,48,0,43.54,0',
#  '3.66,242,0,57.79,0',
#  '22.44,330,0,89.13,0',
#  '9.45,196,0,59.2,0',
#  '9.02,273,2,61.16,1',
#  '9.95,349,0,88.62,0',
#  '41.45,245,0,90.89,0',
#  '11.0,266,0,56.73,0',
#  '55.54,332,0,54.16,0',
#  '47.15,174,0,67.25,0',
#  '32.06,275,0,48.53,0',
#  '36.04,240,0,45.14,0',
#  '126.83,118,0,67.19,0',
#  '257.51,366,1,47.93,1',
#  '75.29,254,0,88.7,0',
#  '288.17,366,2,47.93,1',
#  '570.37,273,3,61.16,1',
#  '70.48,261,0,115.81,0',
#  '43.9,106,0,75.87,0',
#  '5.11,355,0,85.62,0',
#  '20.21,175,0,44.56,0',
#  '88.58,366,0,70.81,0',
#  '1068.48,273,4,61.16,1',
#  '21.17,113,0,81.29,0',
#  '3.52,174,0,72.8,0',
#  '37.32,170,0,94.85,0',
#  '4.48,166,0,59.45,0',
#  '289.82,244,0,53.91,0',
#  '266.28,130,0,70.25,1',
#  '1.12,256,0,62.89,0',
#  '53.61,231,0,51.28,0',
#  '78.09,124,0,88.74,0',
#  '319.22,130,1,70.25,1',
#  '226.35,216,0,96.61,0',
#  '5.34,224,0,61.69,0',
#  '1107.65,365,3,48.97,1',
#  '74.01,244,0,60.27,0',
#  '316.71,273,4,70.25,1',
#  '59.61,174,0,55.82,0',
#  '3.97,177,0,54.85,0',
#  '47.25,299,0,52.22,0',
#  '354.08,365,4,48.97,1',
#  '55.85,286,0,49.26,0',
#  '656.56,163,0,57.15,1',
#  '48.39,224,0,51.54,0',
#  '100.67,224,0,94.24,0',
#  '59.0,162,0,50.73,0',
#  '50.02,56,0,49.23,0',
#  '9.39,71,0,59.39,0',
#  '36.65,63,0,108.45,0',
#  '59.85,156,0,97.28,0',
#  '8.25,170,0,54.88,0',
#  '32.71,166,0,56.76,0',
#  '109.91,239,0,56.4,0',
#  '172.61,352,0,88.16,0',
#  '52.77,292,0,77.03,0',
#  '91.69,108,0,84.14,0',
#  '2.88,191,0,81.77,0',
#  '53.27,117,0,47.87,0',
#  '54.26,228,0,83.55,0',
#  '55.06,172,0,63.87,0',
#  '8.42,119,0,76.8,0',
#  '146.29,218,0,59.96,0',
#  '6.26,121,0,54.47,0',
#  '4.54,106,0,77.92,0',
#  '274.68,273,5,70.25,1',
#  '46.84,327,0,45.4,0',
#  '5.86,343,0,48.86,0',
#  '79.13,221,0,59.39,0',
#  '55.13,119,0,68.63,0',
#  '62.18,132,0,61.13,0',
#  '76.13,187,0,97.83,0',
#  '3.93,173,0,61.62,0',
#  '4.34,237,0,51.89,0',
#  '53.29,217,0,61.52,0',
#  '117.07,224,0,59.66,0',
#  '54.18,216,0,93.56,0',
#  '58.06,292,0,45.62,0',
#  '63.66,67,0,52.14,0',
#  '16.33,327,0,45.4,0',
#  '101.93,287,0,51.88,0',
#  '65.19,183,0,56.14,0',
#  '86.13,124,0,51.5,0',
#  '122.44,176,0,97.37,0',
#  '18.72,149,0,91.46,0',
#  '36.38,191,0,93.22,0',
#  '104.71,169,0,116.02,0',
#  '44.35,181,0,118.88,0',
#  '55.91,114,0,54.27,0',
#  '73.51,237,0,64.68,0',
#  '33.51,101,0,83.85,0',
#  '72.11,359,0,104.9,0',
#  '2.09,299,0,52.22,0',
#  '65.04,165,0,51.45,0',
#  '90.57,191,0,87.89,0',
#  '130.18,257,0,88.74,0',
#  '39.96,234,0,86.55,0',
#  '17.69,189,0,90.5,0',
#  '52.26,277,0,65.69,0',
#  '98.59,293,0,76.27,0',
#  '17.81,236,0,70.45,0',
#  '34.59,159,0,61.15,0',
#  '39.77,288,0,55.02,0',
#  '62.3,58,0,88.03,0',
#  '73.26,171,0,80.79,0',
#  '87.59,62,0,49.89,0',
#  '1.58,343,0,48.86,0',
#  '10.07,239,0,83.83,0',
#  '20.22,302,0,56.09,0',
#  '32.17,302,0,56.25,0',
#  '6.89,271,0,40.07,0',
#  '6.28,352,0,84.96,0',
#  '18.56,170,0,71.77,0',
#  '60.12,288,0,55.02,0',
#  '16.65,176,0,80.08,0',
#  '33.52,220,0,71.56,0',
#  '163.53,228,0,50.82,0',
#  '18.94,109,0,61.79,0',
#  '8.45,242,0,58.66,0',
#  '86.75,101,0,73.95,0',
#  '28.78,244,0,59.98,0',
#  '1.92,316,0,45.68,0',
#  '118.04,291,0,82.31,0',
#  '8.92,103,0,62.44,0',
#  '1.45,159,0,61.15,0',
#  '46.65,53,0,42.77,0',
#  '25.13,260,0,99.53,0',
#  '52.51,176,0,46.88,0',
#  '63.97,157,0,46.43,0',
#  '32.83,253,0,60.67,0',
#  '3.66,286,0,49.26,0',
#  '173.35,118,0,57.38,0',
#  '78.23,123,0,61.6,0',
#  '72.25,170,0,94.85,0',
#  '5.45,162,0,62.12,0',
#  '14.04,272,0,90.59,0',
#  '80.69,255,0,82.46,0',
#  '27.01,110,0,59.54,0',
#  '16.26,376,0,53.93,0',
#  '112.54,219,0,52.18,0',
#  '9.29,52,0,50.13,0',
#  '32.96,119,0,106.64,0',
#  '43.69,153,0,93.05,0',
#  '4.85,244,0,53.91,0',
#  '63.02,250,0,53.95,0',
#  '1.23,268,0,93.01,0',
#  '8.94,254,0,55.68,0',
#  '63.99,268,0,93.01,0',
#  '4.14,113,0,46.35,0',
#  '8.61,277,0,47.56,0',
#  '93.12,123,0,50.27,0',
#  '38.34,176,0,72.37,0',
#  '20.15,53,0,45.92,0',
#  '37.55,248,0,45.16,0',
#  '33.65,187,0,60.21,0',
#  '2.17,123,0,98.31,0',
#  '9.58,382,0,64.8,0',
#  '94.22,171,0,94.98,0',
#  '31.03,351,0,52.45,0',
#  '47.94,176,0,80.08,0',
#  '58.35,344,0,57.44,0',
#  '19.59,178,0,64.96,0',
#  '27.13,299,0,78.86,0',
#  '42.14,232,0,74.27,0',
#  '967.36,273,6,70.25,1',
#  '2.64,288,0,55.02,0',
#  '6.43,123,0,74.34,0',
#  '5.25,213,0,52.45,0',
#  '9.47,65,0,40.96,0',
#  '72.66,222,0,91.22,0',
#  '56.21,123,0,94.24,0',
#  '2.08,187,0,52.06,0',
#  '137.63,240,0,85.69,0',
#  '56.88,328,0,58.39,0',
#  '104.82,342,0,95.03,0',
#  '5.95,166,0,59.74,0',
#  '2.79,118,0,69.14,0',
#  '25.02,266,0,81.15,0',
#  '2.39,115,0,53.96,0',
#  '9.89,237,0,65.26,0',
#  '6.79,191,0,117.35,0',
#  '3.92,240,0,72.74,0',
#  '2.27,60,0,38.14,0',
#  '2.13,289,0,86.55,0',
#  '21.28,163,1,57.15,1',
#  '294.5,277,0,65.32,0',
#  '36.04,162,0,54.86,0',
#  '3.06,113,0,46.35,0',
#  '99.29,102,0,54.81,0',
#  '57.09,44,0,57.77,0',
#  '1086.32,163,2,57.15,1',
#  '5.87,166,0,56.76,0',
#  '28.24,277,0,65.32,0',
#  '48.82,231,0,54.67,0',
#  '1.19,273,0,56.16,0',
#  '4.96,382,0,64.8,0',
#  '220.94,226,0,61.49,0',
#  '118.72,346,0,54.69,0',
#  '21.69,365,2,48.97,1',
#  '65.23,294,0,81.74,0',
#  '29.35,173,0,46.09,0',
#  '78.65,362,0,69.02,0',
#  '104.72,206,0,58.1,0',
#  '18.49,262,0,102.39,0',
#  '419.52,365,3,48.97,1',
#  '33.06,257,0,118.02,0',
#  '6.2,191,0,66.02,0',
#  '690.67,130,2,70.25,1',
#  '799.3,273,3,70.25,1',
#  '64.49,323,0,48.18,0',
#  '143.66,236,0,84.4,0',
#  '106.57,201,0,95.04,0',
#  '10.0,163,3,66.56,1',
#  '17.62,117,0,61.75,0',
#  '68.22,225,0,43.26,0',
#  '66.73,148,0,67.53,0',
#  '7.22,154,0,80.19,0',
#  '74.01,165,0,64.18,0',
#  '9.4,193,0,81.71,0',
#  '4.06,59,0,53.51,0',
#  '846.5,163,4,66.56,1',
#  '94.23,168,0,56.77,0',
#  '125.92,211,0,63.27,0',
#  '56.46,170,0,53.39,0',
#  '92.95,247,0,89.34,0',
#  '2.04,62,0,53.24,0',
#  '57.33,120,0,76.97,0',
#  '103.94,117,0,88.87,0',
#  '80.93,120,0,55.79,0',
#  '4.67,119,0,68.56,0',
#  '97.31,72,0,58.7,0',
#  '42.96,228,0,58.37,0',
#  '70.55,53,0,53.99,0',
#  '52.45,281,0,51.34,0',
#  '92.02,296,0,54.58,0',
#  '93.71,295,0,49.63,0',
#  '18.54,130,1,78.95,1',
#  '65.45,224,0,70.75,0',
#  '88.89,276,0,50.91,0',
#  '197.46,369,0,94.22,0',
#  '63.79,64,0,42.37,0',
#  '108.14,216,0,58.85,0',
#  '55.67,276,0,50.91,0',
#  '172.93,59,0,65.48,0',
#  '74.23,111,0,58.87,0',
#  '50.94,236,0,56.13,0',
#  '211.84,374,0,80.18,0',
#  '14.11,281,0,51.34,0',
#  '104.92,260,0,47.18,0',
#  '77.91,335,0,40.43,0',
#  '57.69,275,0,57.66,0',
#  '221.23,153,0,65.28,0',
#  '217.57,315,0,75.81,0',
#  '319.21,130,2,78.95,1',
#  '76.99,190,0,56.77,0',
#  '2.22,115,0,101.94,0',
#  '125.61,54,0,57.48,0',
#  '50.78,349,0,58.97,0',
#  '190.37,277,0,93.06,0',
#  '188.6,289,0,81.78,0',
#  '5.46,153,0,65.28,0',
#  '69.77,276,0,43.81,0',
#  '70.43,176,0,70.9,0',
#  '224.05,346,0,81.78,0',
#  '45.61,222,0,83.77,0',
#  '7.67,183,0,68.71,0',
#  '53.46,281,0,51.34,0',
#  '82.57,168,0,56.77,0',
#  '99.01,217,0,94.6,0',
#  '40.99,92,0,60.98,0',
#  '9.01,45,0,56.13,0',
#  '87.85,51,0,49.37,0',
#  '55.13,186,0,45.67,0',
#  '8.62,111,0,83.06,0',
#  '2.5,155,0,66.75,0',
#  '206.7,289,0,81.78,0',
#  '89.79,185,0,70.84,0',
#  '107.61,223,0,62.97,0',
#  '176.59,235,0,48.16,0',
#  '409.59,369,0,94.22,0',
#  '56.72,156,0,75.61,0',
#  '1.06,101,0,57.59,0',
#  '101.07,182,0,50.04,0',
#  '65.94,62,0,88.73,0',
#  '1.18,281,0,79.82,0',
#  '113.83,351,0,55.49,0',
#  '5.33,166,0,52.1,0',
#  '66.84,217,0,86.39,0',
#  '35.47,50,0,89.49,0',
#  '66.5,252,0,48.64,0',
#  '133.26,244,0,58.6,0',
#  '64.74,225,0,63.44,0',
#  '87.36,125,0,115.67,0',
#  '66.25,295,0,58.68,0',
#  '9.81,115,0,101.94,0',
#  '1.58,357,0,86.18,0',
#  '87.97,311,0,70.62,0',
#  '91.28,179,0,74.07,0',
#  '2.55,183,0,73.75,0',
#  '321.17,179,0,72.42,0',
#  '106.28,122,0,92.14,0',
#  '121.25,185,0,80.54,0',
#  '37.76,171,0,59.2,0',
#  '71.87,103,0,50.06,0',
#  '2.15,183,0,68.71,0',
#  '182.91,365,0,80.42,0',
#  '1.82,61,0,65.77,0',
#  '107.79,283,0,60.8,0',
#  '6.3,233,0,82.97,0',
#  '57.72,242,0,52.29,0',
#  '34.57,179,0,56.51,0',
#  '72.0,101,0,84.83,0',
#  '13.37,111,0,63.31,0',
#  '133.56,319,0,45.62,0',
#  '94.64,177,0,86.05,0',
#  '63.88,259,0,62.74,0',
#  '207.75,103,0,62.95,0',
#  '6.61,106,0,64.68,0',
#  '2.56,177,0,67.62,0',
#  '105.59,155,0,66.75,0',
#  '122.69,190,0,90.13,0',
#  '56.18,170,0,56.87,0',
#  '78.11,107,0,50.56,0',
#  '60.46,283,0,60.8,0',
#  '74.78,236,0,100.77,0',
#  '2.16,252,0,48.64,0',
#  '86.24,276,0,50.91,0',
#  '5.34,328,0,92.55,0',
#  '23.41,274,0,81.98,0',
#  '23.69,361,0,105.07,0',
#  '127.65,159,0,46.98,0',
#  '1.68,217,0,92.19,0',
#  '8.28,349,0,70.85,0',
#  '65.47,228,0,51.01,0',
#  '4.97,391,0,69.74,0',
#  '18.87,348,0,68.37,0',
#  '25.62,233,0,58.27,0',
#  '10.25,233,0,82.97,0',
#  '76.99,380,0,54.01,0',
#  '22.5,218,0,97.84,0',
#  '28.11,292,0,65.58,0',
#  '17.45,56,0,48.45,1',
#  '90.7,43,0,59.06,0',
#  '131.97,178,0,80.62,0',
#  '71.53,185,0,70.84,0',
#  '7.57,244,0,51.44,0',
#  '12.82,264,0,62.01,0',
#  '114.62,118,0,58.31,0',
#  '6.08,237,0,60.34,0',
#  '61.85,355,0,88.25,0',
#  '183.21,241,0,72.71,0',
#  '1099.03,130,3,78.95,1',
#  '6.22,305,0,61.96,0',
#  '15.06,294,0,84.58,0',
#  '46.44,335,0,59.01,0',
#  '68.73,326,0,104.56,0',
#  '11.08,244,0,59.54,0',
#  '216.42,237,0,71.4,0',
#  '136.49,179,0,50.27,0',
#  '20.21,276,0,43.81,0',
#  '46.22,94,0,89.09,0',
#  '4.96,176,0,40.87,0',
#  '238.09,362,0,68.78,0',
#  '6.24,277,0,91.56,0',
#  '3.18,70,0,70.41,0',
#  '68.13,216,0,90.65,0',
#  '18.07,176,0,56.99,0',
#  '1.17,311,0,70.62,0',
#  '3.34,330,0,58.26,0',
#  '41.53,110,0,58.98,0',
#  '63.66,191,0,51.39,0',
#  '198.21,235,0,68.86,0',
#  '68.88,219,0,84.02,0',
#  '2.95,351,0,55.49,0',
#  '52.0,208,0,66.18,0',
#  '81.17,169,0,87.84,0',
#  '50.51,317,0,63.65,0',
#  '130.7,119,0,79.47,0',
#  '271.83,352,0,82.32,0',
#  '74.89,351,0,48.77,0',
#  '5.0,68,0,50.13,0',
#  '6.2,180,0,68.12,0',
#  '111.86,180,0,55.0,0',
#  '129.65,185,0,78.41,0',
#  '4.67,193,0,46.48,0',
#  '1.29,156,0,37.29,0',
#  '6.4,124,0,61.54,0',
#  '54.87,116,0,73.69,0',
#  '12.06,355,0,65.32,0',
#  '91.19,127,0,57.59,0',
#  '1.7,368,0,92.53,0',
#  '204.76,352,0,82.32,0',
#  '7.93,352,0,82.32,0',
#  '150.93,346,0,81.78,0',
#  '151.07,352,0,82.32,0',
#  '40.7,126,0,80.96,0',
#  '9.01,221,0,61.73,0',
#  '17.55,326,0,104.56,0',
#  '4.08,156,0,53.94,0',
#  '1.49,76,0,121.66,0',
#  '38.95,114,0,54.43,0',
#  '23.55,175,0,53.67,0',
#  '7.91,56,0,44.15,0',
#  '441.32,238,0,83.07,0',
#  '41.6,222,0,83.77,0',
#  '61.45,124,0,97.3,0',
#  '53.42,59,0,50.11,0',
#  '108.01,67,0,52.31,0',
#  '252.55,176,0,56.99,0',
#  '26.11,183,0,73.14,0',
#  '6.14,288,0,51.79,0',
#  '66.47,281,0,51.34,0',
#  '9.55,160,0,97.11,0',
#  '1.06,129,0,84.58,0',
#  '24.68,49,0,129.81,0',
#  '93.42,48,0,63.86,0',
#  '7.42,233,0,68.48,0',
#  '78.53,247,0,89.34,0',
#  '20.78,113,0,58.83,0',
#  '154.01,50,0,42.5,0',
#  '6.4,336,0,50.14,0',
#  '41.62,347,0,57.46,0',
#  '5.33,319,0,58.27,0',
#  '27.37,293,0,52.02,0',
#  '132.76,120,0,64.0,0',
#  '72.77,107,0,50.56,0',
#  '34.31,292,0,65.58,0',
#  '1.1,98,0,54.92,0',
#  '148.64,359,0,68.01,0',
#  '175.25,369,0,67.4,0',
#  '20.48,171,0,37.69,0',
#  '82.71,283,0,98.12,0',
#  '60.24,155,0,66.75,0',
#  '2.28,292,0,65.58,0',
#  '66.97,169,0,47.44,0',
#  '27.96,162,0,51.14,0',
#  '1.92,355,0,85.72,0',
#  '2.21,224,0,51.94,0',
#  '34.27,242,0,52.29,0',
#  '3.47,148,0,62.01,0',
#  '4.02,315,0,75.81,0',
#  '40.53,399,0,66.88,0',
#  '110.07,227,0,52.37,0',
#  '4.99,378,0,53.07,0',
#  '47.96,334,0,45.81,0',
#  '49.13,214,0,105.38,0',
#  '84.13,352,0,82.32,0',
#  '24.89,183,0,73.14,0',
#  '48.94,288,0,55.04,0',
#  '156.39,232,0,83.31,0',
#  '2.69,330,0,58.26,0',
#  '338.94,56,1,48.45,1',
#  '92.7,107,0,57.79,0',
#  '4.7,281,0,51.34,0',
#  '22.33,221,0,59.76,0',
#  '21.94,292,0,65.58,0',
#  '77.03,225,0,43.26,0',
#  '98.15,335,0,40.43,0',
#  '7.48,309,0,53.21,0',
#  '8.26,124,0,50.04,0',
#  '27.67,49,0,39.0,0',
#  '33.47,59,0,65.48,0',
#  '382.96,317,0,63.65,0',
#  '686.99,56,2,48.45,1',
#  '893.8,130,4,78.95,1',
#  '886.33,130,5,78.95,1',
#  '173.43,152,0,90.66,0',
#  '8.58,319,0,45.62,0',
#  '76.02,296,0,83.59,0',
#  '49.51,130,6,78.95,1',
#  '4.97,194,0,38.8,0',
#  '171.14,186,0,83.96,0',
#  '7.36,181,0,80.98,0',
#  '4.61,157,0,76.73,0',
#  '72.83,181,0,80.98,0',
#  '3.51,224,0,70.75,0',
#  '812.13,163,2,66.56,1',
#  '48.26,58,0,49.27,0',
#  '5.8,261,0,51.44,0',
#  '50.09,225,0,52.93,0',
#  '108.59,222,0,83.77,0',
#  '118.62,186,0,99.3,0',
#  '986.43,163,3,66.56,1',
#  '858.73,163,4,66.56,1',
#  '42.2,247,0,53.07,0',
#  '1664.25,174,0,55.32,0',
#  '133.43,64,0,76.93,1',
#  '159.2,238,0,54.39,0',
#  '1.59,386,0,64.76,0',
#  '854.04,56,3,48.45,1',
#  '905.63,56,4,48.45,1',
#  '1073.81,130,7,78.95,1',
#  ...]

# %% [markdown]
# The following helper functions will help write messages into each topic.

# %%
def error_callback(exc):
    raise Exception('Error while sending data to kafka: {0}'.format(str(exc)))

def write_to_kafka(topic_name, items):
  count=0
  producer = KafkaProducer(bootstrap_servers=['127.0.0.1:9092'])
  for key, message in items:
    producer.send(topic_name, key=key.encode('utf-8'),
                  value=message.encode('utf-8')).add_errback(error_callback)
    count+=1
  producer.flush()
  print("Wrote {0} messages into topic: {1}".format(count, topic_name))

# %% [markdown]
# To start with we write 5 messages to each topic.

# %%
write_to_kafka("customerinfo", zip(timestamps[1:6], X_kafka[1:6]))
write_to_kafka("features", zip(timestamps[1:6], featuredata[1:6]))
# Out:
# Wrote 5 messages into topic: customerinfo
# Wrote 5 messages into topic: features

# %% [markdown]
# The zip function pairs up the timestamps with data into tuples.

# %% [markdown]
# Run the following shell command to view one of the topics. You will need to interrupt execution of the cell after the five messages have appeared.

# %%
! /content/kafka_2.13-3.9.0/bin/kafka-console-consumer.sh \
--bootstrap-server localhost:9092 \
--topic features \
--from-beginning
# Out:
# 1061.02,56,5,68.13,1
# 62.68,111,0,92.62,0
# 59.16,215,0,61.68,0
# 93.83,141,0,94.91,0
# 8.62,224,0,70.26,0
# Processed a total of 5 messages

# %% [markdown]
# ## Subscribing to topics
# To start with we subscribe to both topics with the same consumer.

# %%
kafka_bootstrap_servers = 'localhost:9092'
topics = ['customerinfo', 'features']

# %%
consumer = KafkaConsumer(
    *topics,
    group_id = '104a',
    bootstrap_servers=kafka_bootstrap_servers,
    auto_offset_reset='earliest',
    enable_auto_commit=True)

# %%
consumer.config
# Out:
# {'bootstrap_servers': 'localhost:9092',
#  'client_id': 'kafka-python-2.2.15',
#  'group_id': '104a',
#  'key_deserializer': None,
#  'value_deserializer': None,
#  'enable_incremental_fetch_sessions': True,
#  'fetch_max_wait_ms': 500,
#  'fetch_min_bytes': 1,
#  'fetch_max_bytes': 52428800,
#  'max_partition_fetch_bytes': 1048576,
#  'request_timeout_ms': 305000,
#  'retry_backoff_ms': 100,
#  'reconnect_backoff_ms': 50,
#  'reconnect_backoff_max_ms': 30000,
#  'max_in_flight_requests_per_connection': 5,
#  'auto_offset_reset': 'earliest',
#  'enable_auto_commit': True,
#  'auto_commit_interval_ms': 5000,
#  'default_offset_commit_callback': <function kafka.consumer.group.KafkaConsumer.<lambda>(offsets, response)>,
#  'check_crcs': True,
#  'isolation_level': 'read_uncommitted',
#  'allow_auto_create_topics': True,
#  'metadata_max_age_ms': 300000,
#  'partition_assignment_strategy': (kafka.coordinator.assignors.range.RangePartitionAssignor,
#   kafka.coordinator.assignors.roundrobin.RoundRobinPartitionAssignor),
#  'max_poll_records': 500,
#  'max_poll_interval_ms': 300000,
#  'session_timeout_ms': 10000,
#  'heartbeat_interval_ms': 3000,
#  'receive_buffer_bytes': None,
#  'send_buffer_bytes': None,
#  'socket_options': [(6, 1, 1)],
#  'sock_chunk_bytes': 4096,
#  'sock_chunk_buffer_count': 1000,
#  'consumer_timeout_ms': inf,
#  'security_protocol': 'PLAINTEXT',
#  'ssl_context': None,
#  'ssl_check_hostname': True,
#  'ssl_cafile': None,
#  'ssl_certfile': None,
#  'ssl_keyfile': None,
#  'ssl_crlfile': None,
#  'ssl_password': None,
#  'ssl_ciphers': None,
#  'api_version': (2, 6),
#  'api_version_auto_timeout_ms': 2000,
#  'connections_max_idle_ms': 540000,
#  'metric_reporters': [],
#  'metrics_enabled': True,
#  'metrics_num_samples': 2,
#  'metrics_sample_window_ms': 30000,
#  'metric_group_prefix': 'consumer',
#  'selector': selectors.EpollSelector,
#  'exclude_internal_topics': True,
#  'sasl_mechanism': None,
#  'sasl_plain_username': None,
#  'sasl_plain_password': None,
#  'sasl_kerberos_name': None,
#  'sasl_kerberos_service_name': 'kafka',
#  'sasl_kerberos_domain_name': None,
#  'sasl_oauth_token_provider': None,
#  'socks5_proxy': None,
#  'kafka_client': kafka.client_async.KafkaClient}

# %% [markdown]
# The following cell shows the message, key and value of records obtained by the consumer. Stop running of the cell once ten messages have been displayed.

# %%
for message in consumer:
  print("message: ", message)
  print("key: ", message.key)
  print("value: ", message.value.decode('utf-8'))
  time.sleep(2)
# Out:
# message:  ConsumerRecord(topic='customerinfo', partition=0, leader_epoch=0, offset=0, timestamp=1752909741260, timestamp_type=0, key=b'2020-12-01 22:17:33', value=b'377834944388609,Kuhic LLC,shopping_net,1061.02,Michael,Jackson,M,539 Underwood Divide,Pea Ridge,AR,72751,36.4539,-94.118,6434,Product designer,53,56,5,5,68.13,1', headers=[], checksum=None, serialized_key_size=19, serialized_value_size=160, serialized_header_size=-1)
# key:  b'2020-12-01 22:17:33'
# value:  377834944388609,Kuhic LLC,shopping_net,1061.02,Michael,Jackson,M,539 Underwood Divide,Pea Ridge,AR,72751,36.4539,-94.118,6434,Product designer,53,56,5,5,68.13,1
# message:  ConsumerRecord(topic='customerinfo', partition=1, leader_epoch=0, offset=0, timestamp=1752909741260, timestamp_type=0, key=b'2020-12-01 22:23:27', value=b'639030014711,"Schumm, McLaughlin and Carter",food_dining,62.68,Stephen,Lopez,M,696 Matthew Ford Suite 157,Olmsted,IL,62970,37.1935,-89.0933,639,Mechanical engineer,38,111,5,0,92.62,0', headers=[], checksum=None, serialized_key_size=19, serialized_value_size=182, serialized_header_size=-1)
# key:  b'2020-12-01 22:23:27'
# value:  639030014711,"Schumm, McLaughlin and Carter",food_dining,62.68,Stephen,Lopez,M,696 Matthew Ford Suite 157,Olmsted,IL,62970,37.1935,-89.0933,639,Mechanical engineer,38,111,5,0,92.62,0
# message:  ConsumerRecord(topic='customerinfo', partition=1, leader_epoch=0, offset=1, timestamp=1752909741260, timestamp_type=0, key=b'2020-12-01 22:35:42', value=b'4155021259183870,Pollich LLC,home,59.16,Renee,Parrish,F,174 Jennifer Meadow Apt. 467,Mountain Park,OK,73559,34.7032,-98.9591,540,Research scientist (life sciences),37,215,12,0,61.68,0', headers=[], checksum=None, serialized_key_size=19, serialized_value_size=183, serialized_header_size=-1)
# key:  b'2020-12-01 22:35:42'
# value:  4155021259183870,Pollich LLC,home,59.16,Renee,Parrish,F,174 Jennifer Meadow Apt. 467,Mountain Park,OK,73559,34.7032,-98.9591,540,Research scientist (life sciences),37,215,12,0,61.68,0
# message:  ConsumerRecord(topic='customerinfo', partition=1, leader_epoch=0, offset=2, timestamp=1752909741260, timestamp_type=0, key=b'2020-12-01 22:36:03', value=b'4874017206859125,"Mueller, Gerhold and Mueller",health_fitness,93.83,Lauren,Williams,F,065 Jones Stravenue,Lake Oswego,OR,97034,45.4093,-122.6847,42817,Planning and development surveyor,39,141,9,0,94.91,0', headers=[], checksum=None, serialized_key_size=19, serialized_value_size=204, serialized_header_size=-1)
# key:  b'2020-12-01 22:36:03'
# value:  4874017206859125,"Mueller, Gerhold and Mueller",health_fitness,93.83,Lauren,Williams,F,065 Jones Stravenue,Lake Oswego,OR,97034,45.4093,-122.6847,42817,Planning and development surveyor,39,141,9,0,94.91,0
# message:  ConsumerRecord(topic='customerinfo', partition=1, leader_epoch=0, offset=3, timestamp=1752909741260, timestamp_type=0, key=b'2020-12-01 22:38:09', value=b'3513618443244549,Streich Ltd,home,8.62,Amber,Perez,F,954 Reyes Ways,Fulton,SD,57340,43.7588,-97.8712,355,Financial adviser,65,224,14,0,70.26,0', headers=[], checksum=None, serialized_key_size=19, serialized_value_size=142, serialized_header_size=-1)
# key:  b'2020-12-01 22:38:09'
# value:  3513618443244549,Streich Ltd,home,8.62,Amber,Perez,F,954 Reyes Ways,Fulton,SD,57340,43.7588,-97.8712,355,Financial adviser,65,224,14,0,70.26,0
# message:  ConsumerRecord(topic='features', partition=0, leader_epoch=0, offset=0, timestamp=1752909741442, timestamp_type=0, key=b'2020-12-01 22:17:33', value=b'1061.02,56,5,68.13,1', headers=[], checksum=None, serialized_key_size=19, serialized_value_size=20, serialized_header_size=-1)
# key:  b'2020-12-01 22:17:33'
# value:  1061.02,56,5,68.13,1
# message:  ConsumerRecord(topic='features', partition=0, leader_epoch=0, offset=1, timestamp=1752909741442, timestamp_type=0, key=b'2020-12-01 22:23:27', value=b'62.68,111,0,92.62,0', headers=[], checksum=None, serialized_key_size=19, serialized_value_size=19, serialized_header_size=-1)
# key:  b'2020-12-01 22:23:27'
# value:  62.68,111,0,92.62,0
# message:  ConsumerRecord(topic='features', partition=0, leader_epoch=0, offset=2, timestamp=1752909741442, timestamp_type=0, key=b'2020-12-01 22:35:42', value=b'59.16,215,0,61.68,0', headers=[], checksum=None, serialized_key_size=19, serialized_value_size=19, serialized_header_size=-1)
# key:  b'2020-12-01 22:35:42'
# value:  59.16,215,0,61.68,0
# message:  ConsumerRecord(topic='features', partition=0, leader_epoch=0, offset=3, timestamp=1752909741442, timestamp_type=0, key=b'2020-12-01 22:36:03', value=b'93.83,141,0,94.91,0', headers=[], checksum=None, serialized_key_size=19, serialized_value_size=19, serialized_header_size=-1)
# key:  b'2020-12-01 22:36:03'
# value:  93.83,141,0,94.91,0
# message:  ConsumerRecord(topic='features', partition=0, leader_epoch=0, offset=4, timestamp=1752909741442, timestamp_type=0, key=b'2020-12-01 22:38:09', value=b'8.62,224,0,70.26,0', headers=[], checksum=None, serialized_key_size=19, serialized_value_size=18, serialized_header_size=-1)
# key:  b'2020-12-01 22:38:09'
# value:  8.62,224,0,70.26,0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-29-2654336197.py in <cell line: 0>()
# ----> 1 for message in consumer:
#       2   print("message: ", message)
#       3   print("key: ", message.key)
#       4   print("value: ", message.value.decode('utf-8'))
#       5   time.sleep(2)
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in __next__(self)
#    1186                 self._iterator = self._message_generator_v2()
#    1187             try:
# -> 1188                 return next(self._iterator)
#    1189             except StopIteration:
#    1190                 self._iterator = None
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1158     def _message_generator_v2(self):
#    1159         timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161         for tp, records in six.iteritems(record_map):
#    1162             # Generators are stateful, and it is possible that the tp / records
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     682         timer = Timer(timeout_ms)
#     683         while not self._closed:
# --> 684             records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     685             if records:
#     686                 return records
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in _poll_once(self, timer, max_records, update_offsets)
#     729             poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
#     730
# --> 731         self._client.poll(timeout_ms=poll_timeout_ms)
#     732         # after the long poll, we should check whether the group needs to rebalance
#     733         # prior to returning data so that the group can stabilize faster
#
# /usr/local/lib/python3.11/dist-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     683                     timeout = max(0, timeout)  # avoid negative timeouts
#     684
# --> 685                 self._poll(timeout / 1000)
#     686
#     687             # called without the lock to avoid deadlock potential
#
# /usr/local/lib/python3.11/dist-packages/kafka/client_async.py in _poll(self, timeout)
#     726
#     727         start_select = time.time()
# --> 728         ready = self._selector.select(timeout)
#     729         end_select = time.time()
#     730         if self._sensors:
#
# /usr/lib/python3.11/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:

# %% [markdown]
# **Question**: In which order have the records come into the consumer and are the records sorted within each topic?

# %% [markdown]
# **Answer**:
# The recoreds are sorted within each partition but not necessarily within a topic. One topic's results are shown followed by another.

# %% [markdown]
# For the next section we delete and recreate our topics, this time each with one partition.

# %%
# !./kafka_2.13-3.9.0/bin/kafka-topics.sh --delete --bootstrap-server 127.0.0.1:9092 --topic customerinfo
# !./kafka_2.13-3.9.0/bin/kafka-topics.sh --delete --bootstrap-server 127.0.0.1:9092 --topic features

# %%
# !./kafka_2.13-3.9.0/bin/kafka-topics.sh --create --bootstrap-server 127.0.0.1:9092 --replication-factor 1 --partitions 1 --topic customerinfo
# !./kafka_2.13-3.9.0/bin/kafka-topics.sh --create --bootstrap-server 127.0.0.1:9092 --replication-factor 1 --partitions 1 --topic features
# Out:
# Created topic customerinfo.
# Created topic features.

# %%
# !./kafka_2.13-3.9.0/bin/kafka-topics.sh --describe --bootstrap-server 127.0.0.1:9092 --topic customerinfo
# !./kafka_2.13-3.9.0/bin/kafka-topics.sh --describe --bootstrap-server 127.0.0.1:9092 --topic features
# Out:
# Topic: customerinfo	TopicId: Z-RnRmukSImX815jqmqQhg	PartitionCount: 1	ReplicationFactor: 1	Configs:
# 	Topic: customerinfo	Partition: 0	Leader: 0	Replicas: 0	Isr: 0	Elr: N/A	LastKnownElr: N/A
# Topic: features	TopicId: EJCHn93HTCetTMZDXcsGuw	PartitionCount: 1	ReplicationFactor: 1	Configs:
# 	Topic: features	Partition: 0	Leader: 0	Replicas: 0	Isr: 0	Elr: N/A	LastKnownElr: N/A

# %% [markdown]
# ## Creating a map showing the incoming stream

# %% [markdown]
# This time we write more messages to each topic.

# %%
write_to_kafka("customerinfo", zip(timestamps[1:], X_kafka[1:]))
# Out:
# Wrote 6511 messages into topic: customerinfo

# %% [markdown]
# **Exercise**: write featuredata[1:] to the topic "features"

# %%
# ANSWER:
write_to_kafka("features", zip(timestamps[1:], featuredata[1:]))
# Out:
# Wrote 6511 messages into topic: features

# %%
consumer = KafkaConsumer(
    'customerinfo',
    group_id = '104a',
    bootstrap_servers=kafka_bootstrap_servers,
    auto_offset_reset='earliest',
    enable_auto_commit=True)

# %% [markdown]
# Run the following cell to see if the first 20 latitude and longitude values are accessible.

# %%
df_received = pd.DataFrame(columns = ['lat', 'lon'])
count = 0
for message in consumer:
  count = count + 1
  x = re.split(r",(?=(?:[^\"]*\"[^\"]*\")*[^\"]*$)", message.value.decode('utf-8'))
  #source: https://stackoverflow.com/questions/18893390/splitting-on-comma-outside-quotes
  #this regular expression allows one to split the record only on commas occurring outside quote
  #characters
  df_received = pd.concat([df_received, pd.DataFrame({'lat': [x[11]], 'lon': [x[12]]})], ignore_index=True)
  print(f"lat = %s, lon = %s" %  (x[11], x[12]))
  time.sleep(1)
  if count > 20:
    break
# Out:
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Heartbeat failed for group 104a because it is rebalancing
# WARNING:kafka.coordinator.heartbeat:Consumer poll timeout has expired. This means the time between subsequent calls to poll() was longer than the configured max_poll_interval_ms, which typically implies that the poll loop is spending too much time processing messages. You can address this either by increasing max_poll_interval_ms or by reducing the maximum size of batches returned in poll() with max_poll_records.
# lat = 36.4539, lon = -94.118
# lat = 37.1935, lon = -89.0933
# lat = 34.7032, lon = -98.9591
# lat = 45.4093, lon = -122.6847
# lat = 43.7588, lon = -97.8712
# lat = 43.0048, lon = -108.8964
# lat = 43.0048, lon = -108.8964
# lat = 36.4539, lon = -94.118
# lat = 29.479, lon = -95.9681
# lat = 43.6498, lon = -116.4306
# lat = 44.3566, lon = -103.6999
# lat = 47.2271, lon = -117.0819
# lat = 42.9207, lon = -91.0685
# lat = 46.0062, lon = -86.2555
# lat = 40.5891, lon = -75.4645
# lat = 26.4215, lon = -99.0025
# lat = 39.7532, lon = -105.6356
# lat = 27.5517, lon = -81.8074
# lat = 40.4603, lon = -79.0097
# lat = 33.4629, lon = -86.7904
# lat = 39.0965, lon = -84.6431

# %% [markdown]
# Another way of getting records from the consumer is through the poll method:

# %%
latestrecord = consumer.poll(max_records = 1)

# %%
latestrecord # one record should appear, if not rerun the above cell
# Out:
# {TopicPartition(topic='customerinfo', partition=0): [ConsumerRecord(topic='customerinfo', partition=0, leader_epoch=0, offset=21, timestamp=1752910459967, timestamp_type=0, key=b'2020-12-01 23:36:02', value=b'6011366578560244,Abshire PLC,entertainment,9.3,Adam,Stark,M,0912 Mark Fields Apt. 080,Mc Veytown,PA,17051,40.5046,-77.7186,4653,Nutritional therapist,23,244,16,0,43.38,0', headers=[], checksum=None, serialized_key_size=19, serialized_value_size=169, serialized_header_size=-1)]}

# %%
records = consumer.poll(max_records = 3)
for tp, consumer_records in records.items():
    for consumer_record in consumer_records:
        print("offset: ", consumer_record.offset, "record value: ",
              consumer_record.value)
# Out:
# offset:  22 record value:  b'675945690716,"Prosacco, Kreiger and Kovacek",home,54.6,Ellen,Smith,F,285 George Lake,Beaver Falls,PA,15010,40.7687,-80.3592,28425,Podiatrist,20,152,11,0,51.05,0'
# offset:  23 record value:  b'4149635823017,Reilly LLC,home,6.38,Samuel,Farrell,M,428 Michael Tunnel Apt. 377,Cleveland,AL,35049,33.9778,-86.5598,3996,Aid worker,43,241,12,0,49.52,0'
# offset:  24 record value:  b'4956828990005111019,Effertz LLC,entertainment,436.63,Kenneth,Robinson,M,269 Sanchez Rapids,Elizabeth,NJ,7208,40.6747,-74.2239,124967,Operational researcher,40,271,11,0,50.39,0'

# %% [markdown]
# The following function obtains the latest record from *consumer*.

# %%
def get_latest_record():
    global consumer

    latestrecord = consumer.poll(max_records = 1)
    for tp, consumer_record in latestrecord.items():
      for message in consumer_record:
        x = re.split(r",(?=(?:[^\"]*\"[^\"]*\")*[^\"]*$)", message.value.decode('utf-8'))

        y = message.key.decode('utf-8')

    return [y] + x

# %% [markdown]
# **Exercise**: run get_latest_record() a couple of times to verify that different records are obtained from the consumer each time.

# %%
get_latest_record()
# Out:
# ['2020-12-01 23:40:01',
#  '3511378610369890',
#  '"Graham, Hegmann and Hammes"',
#  'food_dining',
#  '2.48',
#  'James',
#  'Cooper',
#  'M',
#  '663 Ramirez Trace Apt. 951',
#  'Huntsville',
#  'AL',
#  '35811',
#  '34.7789',
#  '-86.5438',
#  '190178',
#  'Television production assistant',
#  '48',
#  '280',
#  '13',
#  '0',
#  '54.8',
#  '0']

# %%
get_latest_record()
# Out:
# ['2020-12-01 23:46:46',
#  '2252055259910912',
#  'Ziemann-Waters',
#  'health_fitness',
#  '77.24',
#  'Jason',
#  'Hernandez',
#  'M',
#  '220 Frank Gardens',
#  'Hewitt',
#  'WI',
#  '54441',
#  '44.6437',
#  '-90.1031',
#  '828',
#  'Arts development officer',
#  '29',
#  '215',
#  '9',
#  '0',
#  '94.13',
#  '0']

# %% [markdown]
# Reinitialising the customerinfo *consumer*:

# %%
consumer = KafkaConsumer(
    'customerinfo',
    group_id = '104a',
    bootstrap_servers=kafka_bootstrap_servers,
    auto_offset_reset='earliest',
    enable_auto_commit=True)

# %% [markdown]
# The following cell creates a dashboard app to display a map showing location of each customer Some additional data appears when hovering over a dot on the map.

# %%
try:
  del(trans_info)
except:
  pass

trans_info = pd.DataFrame(columns = ['time', 'merchant', 'category', 'amount',
                                      'city', 'lat', 'lon', 'text'])

app = Dash(__name__)

app.layout = html.Div([
    dcc.Graph(id='demo-live'),
    # every two seconds the layout updates:
    dcc.Interval(id='output-update', interval=2*1000)
])

@app.callback(
    Output(component_id='demo-live', component_property='figure'),
    [Input(component_id='output-update', component_property='n_intervals')]
)
def get_live_updates(n_intervals):
    global trans_info
    newrow = get_latest_record() #newrow is a list

    trans_info = pd.concat([trans_info, pd.DataFrame({
        'time': [newrow[0]],
        'merchant': [newrow[2]],
        'category': [newrow[3]],
        'amount': [newrow[4]],
        'city': [newrow[9]],
        'lat': [newrow[12]],
        'lon': [newrow[13]],
        'text': ['Time: ' + newrow[0] + '<br>Merchant: ' + newrow[2] \
        + '<br>Category: ' + newrow[3]\
        + '<br>Amount: ' + newrow[4] + '' + '<br>City: '\
        + newrow[9]]
        })], ignore_index=True)

    time.sleep(1)
    df2 = trans_info.copy()

    data=go.Scattergeo(
          lon = df2['lon'],
          lat = df2['lat'],
          text = df2['text'],
          locationmode = 'USA-states',
          mode = 'markers',
        )

    layout = go.Layout(
          autosize=False,
          width=780,
          height=500,
          margin=dict(l=20, r=20, t=20, b=20),
          paper_bgcolor='lightblue',
          geo_scope='usa',
          title_text='Locations of Transactions'
        )
    fig = {'data' : [data], 'layout' : layout}

    return fig

# %% [markdown]
# Upon running the following code it may take a few moments for a map to appear. Hover your mouse over any of the dots to reveal more information. Aim to understand the workings of the previous cell.

# %%
app.run() # run after a few seconds

# %% [markdown]
# While the app is running, run the following cell several times to verify that data is streaming into the consumer.

# %%
trans_info.tail()
# Out:
#                    time                   merchant       category  amount  \
# 16  2020-12-02 02:27:44              Koepp-Witting    grocery_pos   116.6
# 17  2020-12-02 02:55:59  "Casper, Hand and Zulauf"    grocery_pos  131.93
# 18  2020-12-02 02:56:16            Cummerata-Jones  gas_transport   10.75
# 19  2020-12-02 03:15:28                 Rempel Inc   shopping_net   93.07
# 20  2020-12-02 03:32:10                  Lynch Ltd   shopping_pos  106.38
#
#               city      lat        lon  \
# 16  Mulberry Grove  38.9311   -89.2463
# 17           Enola  35.2087   -92.2123
# 18       Pea Ridge  36.4539    -94.118
# 19            Egan   30.251   -92.5002
# 20         Boulder  46.2306  -112.1138
#
#                                                  text
# 16  Time: 2020-12-02 02:27:44<br>Merchant: Koepp-W...
# 17  Time: 2020-12-02 02:55:59<br>Merchant: "Casper...
# 18  Time: 2020-12-02 02:56:16<br>Merchant: Cummera...
# 19  Time: 2020-12-02 03:15:28<br>Merchant: Rempel ...
# 20  Time: 2020-12-02 03:32:10<br>Merchant: Lynch L...

# %% [markdown]
# If there's a need to restart the consumer (e.g. a heartbeat failed warning appears because it is rebalancing), one can run consumer.close() and then recreate the consumer.

# %% [markdown]
# ## Live predictions

# %% [markdown]
# Finally we use the features topic to make fraud predictions on the fly with a trained classification model.
#
# We use the first 90000 records of df as the training set.

# %%
X_train = df[predictors][:90000]
y_train = df['is_fraud'][:90000]

# %% [markdown]
# **Exercise**: Fit a classification model to X_train, y_train and score it. (For this lab it does not matter how well or poorly the model performs.)

# %%
# ANSWER
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth=10, random_state=0)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=0)

# %%
rf.score(df[predictors][9000:], df['is_fraud'][9000:])
# Out:
# 0.9936007313449892

# %% [markdown]
# Subscribe to the topic containing the predictors and perform live predictions.

# %%
feature_consumer = KafkaConsumer(
    'features',
    group_id = '104b',
    bootstrap_servers=kafka_bootstrap_servers,
    auto_offset_reset='earliest',
    enable_auto_commit=True)

# %%
def get_latest_customer_features():
    global feature_consumer

    # Poll the consumer for the latest record
    latestrecord = feature_consumer.poll(max_records=1)

    # Default values for x and y in case no records are returned
    x = []
    y = None

    # Check if there are any records in the poll result
    if latestrecord:
        for tp, consumer_record in latestrecord.items():
            for message in consumer_record:
                x = re.split(r",", message.value.decode('utf-8'))
                y = message.key.decode('utf-8')

    # Ensure that x and y are always returned as a list, even if no records were processed
    return [y] + x if y is not None else x

# %%
get_latest_customer_features() #may need to wait a few moments before the consumer is ready
# Out:
# ['2020-12-02 12:57:42', '5.71', '286', '0', '92.26', '0']

# %% [markdown]
# The following is a function to be used in our next dashboard to output the type of predicted result (True/False Positives, True/False Negatives):

# %%
def prediction_result(predicted_outcome, actual_outcome):
  # predicted   actual    output
  #    0           0        TN
  #    0           1        FN
  #    1           0        FP
  #    1           1        TP

  key = predicted_outcome*2 + actual_outcome
  mappingdict = {0: 'TN', 1: 'FN', 2: 'FP', 3: 'TP'}
  return mappingdict[key]

# %%
try:
  del(df_preds)
except:
  pass
df_preds = pd.DataFrame(columns = ['datetime'] + predictors +
                        ['predicted_output', 'actual_output', 'result'])

# %% [markdown]
# **Exercise**: The next cell creates a dashboard showing predictions made live. Fill in the missing code to generate predicted output based on your trained model.

# %%
app = Dash(__name__)

app.layout = html.Div([
    dcc.Graph(id='demo-live'),
    ## for every 2 secs the layout updates
    dcc.Interval(id='output-update', interval=2*1000)
])

@app.callback(
    Output(component_id='demo-live', component_property='figure'),
    [Input(component_id='output-update', component_property='n_intervals')]
)
def get_live_updates(n_intervals):
    global df_preds
    newrow = get_latest_customer_features()
    predicted_output = int(rf.predict([newrow[1:-1]]))
    df_preds = pd.concat([df_preds, pd.DataFrame({'datetime': [newrow[0]],
                               'amount': [newrow[1]],
                               'num_trans_60d': [newrow[2]],
                               'num_fraud_trans_24h': [newrow[3]],
                               'avg_trans_amt_60d': [newrow[4]],
                               'predicted_output': [predicted_output],
                               'actual_output': [newrow[5]],
                               'result': [prediction_result(int(predicted_output),
                                                           int(newrow[5]))]})],
                               ignore_index=True)

    time.sleep(1)
    df2 = df_preds.copy()
    last20 = df2.tail(20)

    fig = make_subplots(
      rows=2, cols=2,
      row_heights=[0.1, 0.9],
      column_widths=[0.5, 0.5],
      specs=[[{"type": "Table", "colspan": 2}, None],
             [{"type": "Histogram"}, {"type": "Table"}]]
             )

    fig.add_trace(
        go.Table(
            header=dict(
                values=["False Positive Count", "False Negative Count"],
                font=dict(size=14),
                align="center"
            ),
            cells=dict(
                values=[sum(df_preds['result'] == 'FP'),
                        sum(df_preds['result'] == 'FN')],
            align = "center"),
            columnwidth = [.5, .5]
        ),
        row=1, col=1
    )

    fig.add_trace(
      go.Histogram(x=df2['amount'].astype(float),
                 xbins = dict(start = 0, end=500, size=20)
                 ),
      row=2, col=1
    )
    fig.update_xaxes(title_text="Amount Spent", row=2, col=1)
    fig.update_yaxes(title_text="Count", row=2, col=1)

    fig.add_trace(
      go.Table(
        header=dict(
            values=["Datetime", "Predicted Outcome", "Actual Outcome",
                    "Result"],
            font=dict(size=14),
            align="center"
        ),
        cells=dict(
            values=[last20['datetime'], last20['predicted_output'],
                              last20['actual_output'], last20['result']],
            align = "center"),
        columnwidth = [.27, .27, .27, .19]
      ),
    row=2, col=2
    )
    fig.update_layout(
    height=800,
    showlegend=False,
    title_text="Live Results",
    )
    return fig

# %%
app.run()

# %% [markdown]
# **Exercise**: While the app is running verify that df_preds is being modified.

# %%
df_preds.tail()
# Out:
#                datetime  amount num_trans_60d num_fraud_trans_24h  \
# 35  2020-12-02 01:12:17   72.07           185                   0
# 36  2020-12-02 01:19:18    5.48           188                   0
# 37  2020-12-02 01:20:41   26.63           164                   0
# 38  2020-12-02 01:21:34  104.55           111                   0
# 39  2020-12-02 01:33:38   64.24           261                   0
#
#    avg_trans_amt_60d predicted_output actual_output result
# 35             90.52                0             0     TN
# 36             61.51                0             0     TN
# 37             53.14                0             0     TN
# 38            124.15                0             0     TN
# 39             51.36                0             0     TN

# %% [markdown]
# ## Conclusion
# We have implemented a simple Kakfa streaming platform to which we published to topics - one with customer information, the other a subset of that to make fraud predictions. With the first topic we generated a live map showing the locations of customers, in the other we created a live predictive model scoring dashboard.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2025 Institute of Data
#
#
# ---
#
#
#
# ---
